# %%
# %load_ext autoreload
# %autoreload 2

UNIQUE_VALUES_THRESHOLD = 200
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy
import pandas

# %%
def analyze(scores: pandas.DataFrame, by, filters = [], agg = 'mean'):
    scores["score"] = scores["subj1"] + scores["subj2"] + scores["subj3"]
    scores[["Source", "Algorithm", "Dimension", "Stat"]] = scores['name'].str.split(' ', expand = True)
    for filt in filters:
        scores = filt(scores)

    scores = scores[[by, "score"]]
    print('Features: ', scores.shape[0])
    match agg:
        case 'mean':
            stats = scores.groupby(by = by).mean().reset_index()
        case 'count':
            stats = scores.groupby(by = by).count().reset_index()
    return stats.sort_values(by = 'score', ascending = False)

# %% [markdown]
# ### QSDA

# %%
def construct_joint_qsda():
    scores1 = pandas.read_csv("Subj1/exp_full_flow/qsda/scores.csv")
    scores1["score"] = scores1["score"] * (scores1["unique_values"] >= UNIQUE_VALUES_THRESHOLD)
    
    scores2 = pandas.read_csv("Subj2/exp_full_flow/qsda/scores.csv")
    scores2["score"] = scores2["score"] * (scores2["unique_values"] >= UNIQUE_VALUES_THRESHOLD)

    scores3 = pandas.read_csv("Subj3/exp_full_flow/qsda/scores.csv")
    scores3["score"] = scores3["score"] * (scores3["unique_values"] >= UNIQUE_VALUES_THRESHOLD)
    
    scores = scores1.join(scores2, lsuffix = "_subj1", rsuffix = "_subj2").join(scores3, rsuffix = "_subj3")
    scores = scores[["name_subj1", "score_subj1", "score_subj2", "score" ]]
    scores = scores.rename(columns = { 'name_subj1': 'name', 'score_subj1': 'subj1', 'score_subj2': 'subj2', 'score': 'subj3' })

    return scores

# %%
def filter1(scores):
    scores = scores[scores["Stat"] != "percentile-25"]
    scores = scores[scores["Stat"] != "median"]
    scores = scores[scores["Stat"] != "percentile-75"]
    scores = scores[scores["Stat"] != "skew"]
    scores = scores[scores["Stat"] != "kurtosis"]
    return scores

display(analyze(construct_joint_qsda(), by = 'Stat'))
display(analyze(construct_joint_qsda(), by = 'Stat', filters = [ filter1 ]))
# Out:
# Features:  19143
#              Stat     score
# 2            mean  2.418383
# 4          norm-1  2.320092
# 10            sum  2.320092
# 5          norm-2  2.090892
# 9             std  2.003843
# 1             max  1.798580
# 0        kurtosis  1.329754
# 3          median  1.181211
# 7   percentile-75  1.043281
# 8            skew  0.960317
# 6   percentile-25  0.937652
# Features:  12543
#      Stat     score
# 1    mean  2.418383
# 2  norm-1  2.320092
# 5     sum  2.320092
# 3  norm-2  2.090892
# 4     std  2.003843
# 0     max  1.798580

# %%
def filter2(scores):
    scores = scores[scores["Dimension"] != "all"]
    scores = scores[scores["Dimension"] != "dim-4"]
    scores = scores[scores["Dimension"] != "dim-5"]
    return scores

display(analyze(construct_joint_qsda(), by = 'Dimension', filters = [ filter1 ]))
display(analyze(construct_joint_qsda(), by = 'Dimension', filters = [ filter1, filter2 ]))
# Out:
# Features:  12543
#   Dimension     score
# 7    norm-2  3.216626
# 6    norm-1  3.112098
# 1     dim-1  2.852267
# 0       all  2.792760
# 2     dim-2  2.210085
# 3     dim-3  1.739903
# 4     dim-4  1.299172
# 5     dim-5  0.922026
# Features:  9339
#   Dimension     score
# 4    norm-2  3.216626
# 3    norm-1  3.112098
# 0     dim-1  2.852267
# 1     dim-2  2.210085
# 2     dim-3  1.739903

# %%
def filter3(scores):
    scores = scores[scores["Algorithm"] != "betti"]
    scores = scores[scores["Algorithm"] != "numberofpoints"]
    scores = scores[scores["Algorithm"] != "amplitude-betti-1"]
    scores = scores[scores["Algorithm"] != "amplitude-betti-2"]
    return scores

display(analyze(construct_joint_qsda(), by = 'Algorithm', filters = [ filter1, filter2 ]))
display(analyze(construct_joint_qsda(), by = 'Algorithm', filters = [ filter1, filter2, filter3 ]))
# Out:
# Features:  9339
#                    Algorithm     score
# 8   amplitude-silhouette-1-2  4.008034
# 7   amplitude-silhouette-1-1  3.961057
# 3    amplitude-landscape-1-1  3.495149
# 4    amplitude-landscape-1-2  3.345452
# 19              silhouette-1  3.336270
# 9   amplitude-silhouette-2-1  3.310503
# 20              silhouette-2  3.301615
# 10  amplitude-silhouette-2-2  3.284384
# 5    amplitude-landscape-2-1  2.937374
# 16                 landscape  2.915710
# 6    amplitude-landscape-2-2  2.882430
# 15                   entropy  2.670963
# 13                       bd2  2.542298
# 12   amplitude-wasserstein-2  2.435086
# 11   amplitude-wasserstein-1  2.377893
# 2       amplitude-bottleneck  2.275149
# 17                      life  2.249071
# 1          amplitude-betti-2  1.223968
# 0          amplitude-betti-1  1.195894
# 14                     betti  0.101785
# 18            numberofpoints  0.000000
# Features:  7728
#                    Algorithm     score
# 6   amplitude-silhouette-1-2  4.008034
# 5   amplitude-silhouette-1-1  3.961057
# 1    amplitude-landscape-1-1  3.495149
# 2    amplitude-landscape-1-2  3.345452
# 15              silhouette-1  3.336270
# 7   amplitude-silhouette-2-1  3.310503
# 16              silhouette-2  3.301615
# 8   amplitude-silhouette-2-2  3.284384
# 3    amplitude-landscape-2-1  2.937374
# 13                 landscape  2.915710
# 4    amplitude-landscape-2-2  2.882430
# 12                   entropy  2.670963
# 11                       bd2  2.542298
# 10   amplitude-wasserstein-2  2.435086
# 9    amplitude-wasserstein-1  2.377893
# 0       amplitude-bottleneck  2.275149
# 14                      life  2.249071

# %%
def filter4(scores):
    for source in numpy.unique(scores["Source"]):
        if source.startswith("dissim"):
            scores = scores[scores["Source"] != source]
    return scores

display(analyze(construct_joint_qsda(), by = 'Source', filters = [ filter1, filter2, filter3, filter4 ]).head(60))
# Out:
# Features:  4176
#         Source     score
# 3   channel-11  5.223644
# 35   channel-7  5.013056
# 25  channel-31  4.912045
# 18  channel-25  4.844955
# 37   channel-9  4.763065
# 0    channel-0  4.743569
# 15  channel-22  4.608109
# 17  channel-24  4.560234
# 1    channel-1  4.547576
# 11  channel-19  4.547441
# 24  channel-30  4.471276
# 19  channel-26  4.419265
# 31  channel-37  4.345059
# 21  channel-28  4.342587
# 4   channel-12  4.270636
# 22  channel-29  4.204473
# 32   channel-4  4.129416
# 23   channel-3  4.097685
# 20  channel-27  4.001900
# 26  channel-32  3.995903
# 6   channel-14  3.914995
# 10  channel-18  3.876277
# 14  channel-21  3.848196
# 9   channel-17  3.846835
# 28  channel-34  3.810398
# 12   channel-2  3.804351
# 27  channel-33  3.800729
# 30  channel-36  3.793055
# 29  channel-35  3.741946
# 8   channel-16  3.719109
# 7   channel-15  3.671589
# 16  channel-23  3.546851
# 33   channel-5  3.488079
# 34   channel-6  3.481349
# 2   channel-10  3.350732
# 38     overall  3.341289
# 36   channel-8  3.323604
# 5   channel-13  3.220501
# 13  channel-20  2.862854

# %%
scores = construct_joint_qsda()
scores["score"] = scores["subj1"] + scores["subj2"] + scores["subj3"]
scores[["Source", "Algorithm", "Dimension", "Stat"]] = scores['name'].str.split(' ', expand = True)
for filt in [ filter1, filter2, filter3, filter4 ]:
    scores = filt(scores)
scores = scores.reset_index(drop = True)
display(scores)
# Out:
#                                   name     subj1     subj2     subj3  \
# 0        channel-0 landscape dim-1 max  2.048583  1.010298  1.687861
# 1       channel-0 landscape dim-1 mean  2.457866  1.310240  2.395157
# 2        channel-0 landscape dim-1 std  2.235899  1.314854  2.078066
# 3        channel-0 landscape dim-1 sum  2.457866  1.310240  2.395157
# 4     channel-0 landscape dim-1 norm-1  2.457866  1.310240  2.395157
# ...                                ...       ...       ...       ...
# 4171            overall bd2 dim-3 mean  1.220762  1.471759  2.207955
# 4172             overall bd2 dim-3 std  1.708366  0.442976  0.700258
# 4173             overall bd2 dim-3 sum  1.910437  0.264090  0.989711
# 4174          overall bd2 dim-3 norm-1  1.910437  0.264090  0.989711
# 4175          overall bd2 dim-3 norm-2  1.796962  0.369684  0.906473
#
#          score     Source  Algorithm Dimension    Stat
# 0     4.746743  channel-0  landscape     dim-1     max
# 1     6.163264  channel-0  landscape     dim-1    mean
# 2     5.628818  channel-0  landscape     dim-1     std
# 3     6.163264  channel-0  landscape     dim-1     sum
# 4     6.163264  channel-0  landscape     dim-1  norm-1
# ...        ...        ...        ...       ...     ...
# 4171  4.900476    overall        bd2     dim-3    mean
# 4172  2.851600    overall        bd2     dim-3     std
# 4173  3.164238    overall        bd2     dim-3     sum
# 4174  3.164238    overall        bd2     dim-3  norm-1
# 4175  3.073119    overall        bd2     dim-3  norm-2
#
# [4176 rows x 9 columns]

# %%
def validate(subj):
    match subj:
        case 'Subj1':
            QSDA_THRESHOLD = 0.4
        case 'Subj2':
            QSDA_THRESHOLD = 0.28
        case 'Subj3':
            QSDA_THRESHOLD = 0.32

    cou = 0
    src = pandas.read_csv(f"{subj}/exp_full_flow/qsda/scores.csv")
    src["selected"] = (src["unique_values"] >= UNIQUE_VALUES_THRESHOLD) & (src["normalized_score"] >= QSDA_THRESHOLD)
    for _, row in src.iterrows():
        if not row["selected"]:
            continue
        if "all" in row["name"]:
            continue
        if "dissim" not in row["name"]:
            continue
        if row["name"] in scores["name"].to_numpy():
            continue
        print(row["name"])
        cou += 1
    print(f"Missed {cou} features")

# %%
validate("Subj1")
# Out:
# dissim-0 landscape dim-1 kurtosis
# dissim-0 silhouette-2 dim-1 kurtosis
# dissim-0 entropy dim-1
# dissim-0 life dim-1 percentile-25
# dissim-0 life dim-1 median
# dissim-0 bd2 dim-2 std
# dissim-1 landscape dim-1 kurtosis
# dissim-1 entropy dim-1
# dissim-1 amplitude-landscape-1-2 dim-3
# dissim-1 life dim-2 std
# dissim-1 bd2 dim-2 std
# dissim-2 entropy dim-1
# dissim-2 amplitude-landscape-1-2 dim-3
# dissim-3 landscape dim-3 mean
# dissim-3 landscape dim-3 sum
# dissim-3 landscape dim-3 norm-1
# dissim-3 entropy dim-1
# dissim-3 amplitude-landscape-1-1 dim-3
# dissim-3 bd2 dim-2 std
# dissim-4 landscape dim-1 kurtosis
# dissim-4 entropy dim-1
# dissim-4 amplitude-landscape-1-2 dim-3
# dissim-4 amplitude-landscape-2-2 dim-3
# dissim-4 bd2 dim-2 std
# dissim-5 landscape dim-1 kurtosis
# dissim-5 silhouette-1 dim-1 kurtosis
# dissim-5 silhouette-2 dim-1 kurtosis
# dissim-5 bd2 dim-2 std
# dissim-6 landscape dim-2 mean
# dissim-6 landscape dim-2 sum
# dissim-6 landscape dim-2 norm-1
# dissim-6 landscape dim-3 mean
# dissim-6 landscape dim-3 sum
# dissim-6 landscape dim-3 norm-1
# dissim-6 silhouette-1 dim-2 mean
# dissim-6 silhouette-1 dim-2 sum
# dissim-6 silhouette-1 dim-2 norm-1
# dissim-6 silhouette-2 dim-2 mean
# dissim-6 silhouette-2 dim-2 sum
# dissim-6 silhouette-2 dim-2 norm-1
# dissim-6 amplitude-landscape-1-1 dim-2
# dissim-6 amplitude-landscape-1-1 dim-3
# dissim-6 amplitude-landscape-1-2 dim-2
# dissim-6 amplitude-landscape-1-2 dim-3
# dissim-6 amplitude-silhouette-1-1 dim-2
# dissim-6 amplitude-silhouette-1-2 dim-2
# dissim-6 bd2 dim-2 std
# dissim-7 entropy dim-1
# dissim-7 amplitude-wasserstein-1 dim-3
# dissim-7 life dim-3 sum
# dissim-7 life dim-3 norm-1
# dissim-8 landscape dim-1 kurtosis
# dissim-8 silhouette-1 dim-1 kurtosis
# dissim-8 silhouette-2 dim-1 kurtosis
# dissim-8 bd2 dim-2 std
# dissim-9 bd2 dim-2 std
# dissim-10 bd2 dim-2 std
# dissim-11 entropy dim-1
# dissim-12 entropy dim-1
# dissim-12 life dim-1 percentile-25
# dissim-13 landscape dim-1 kurtosis
# dissim-13 silhouette-1 dim-1 kurtosis
# dissim-13 silhouette-2 dim-1 kurtosis
# dissim-13 life dim-1 percentile-25
# dissim-14 landscape dim-1 kurtosis
# dissim-14 silhouette-1 dim-1 kurtosis
# dissim-14 silhouette-2 dim-1 kurtosis
# dissim-14 silhouette-2 dim-3 mean
# dissim-14 silhouette-2 dim-3 sum
# dissim-14 silhouette-2 dim-3 norm-1
# dissim-14 entropy dim-1
# dissim-14 amplitude-silhouette-1-2 dim-3
# dissim-15 entropy dim-1
# dissim-15 amplitude-landscape-1-2 dim-3
# dissim-16 entropy dim-1
# dissim-16 bd2 dim-2 std
# dissim-17 bd2 dim-2 std
# dissim-18 landscape dim-1 kurtosis
# dissim-18 silhouette-1 dim-1 kurtosis
# dissim-18 silhouette-2 dim-1 kurtosis
# dissim-18 silhouette-2 dim-3 mean
# dissim-18 silhouette-2 dim-3 sum
# dissim-18 silhouette-2 dim-3 norm-1
# dissim-18 entropy dim-1
# dissim-18 amplitude-silhouette-1-2 dim-3
# dissim-18 life dim-1 percentile-25
# dissim-18 bd2 dim-2 std
# dissim-19 entropy dim-1
# dissim-19 bd2 dim-2 std
# dissim-20 entropy dim-1
# dissim-20 life dim-1 percentile-25
# dissim-20 bd2 dim-2 std
# dissim-21 landscape dim-1 kurtosis
# dissim-21 entropy dim-1
# dissim-21 bd2 dim-2 std
# dissim-22 entropy dim-1
# dissim-22 amplitude-landscape-1-2 dim-3
# dissim-22 life dim-1 percentile-25
# dissim-23 silhouette-2 dim-4 mean
# dissim-23 silhouette-2 dim-4 sum
# dissim-23 silhouette-2 dim-4 norm-1
# dissim-23 entropy dim-3
# dissim-23 amplitude-silhouette-1-2 dim-4
# Missed 103 features

# %%
validate("Subj2")
# Out:
# dissim-0 landscape dim-5 mean
# dissim-0 landscape dim-5 sum
# dissim-0 landscape dim-5 norm-1
# dissim-0 silhouette-1 dim-1 median
# dissim-0 silhouette-1 dim-5 mean
# dissim-0 silhouette-1 dim-5 sum
# dissim-0 silhouette-1 dim-5 norm-1
# dissim-0 silhouette-2 dim-1 median
# dissim-0 silhouette-2 dim-5 mean
# dissim-0 silhouette-2 dim-5 sum
# dissim-0 silhouette-2 dim-5 norm-1
# dissim-0 entropy dim-1
# dissim-0 amplitude-landscape-1-1 dim-5
# dissim-0 amplitude-landscape-1-2 dim-5
# dissim-0 amplitude-silhouette-1-1 dim-5
# dissim-0 amplitude-silhouette-1-2 dim-5
# dissim-1 landscape dim-1 median
# dissim-1 silhouette-1 dim-1 median
# dissim-1 silhouette-2 dim-1 median
# dissim-1 entropy dim-1
# dissim-1 amplitude-landscape-1-2 dim-5
# dissim-1 bd2 dim-4 std
# dissim-2 landscape dim-5 max
# dissim-2 silhouette-1 dim-5 mean
# dissim-2 silhouette-1 dim-5 sum
# dissim-2 silhouette-1 dim-5 norm-1
# dissim-2 silhouette-2 dim-1 median
# dissim-2 silhouette-2 dim-5 max
# dissim-2 silhouette-2 dim-5 mean
# dissim-2 silhouette-2 dim-5 sum
# dissim-2 silhouette-2 dim-5 norm-1
# dissim-2 silhouette-2 dim-5 norm-2
# dissim-2 entropy dim-1
# dissim-2 amplitude-silhouette-1-1 dim-5
# dissim-2 amplitude-silhouette-1-2 dim-5
# dissim-2 amplitude-silhouette-2-2 dim-5
# dissim-3 entropy dim-1
# dissim-3 bd2 dim-4 std
# dissim-4 landscape dim-1 median
# dissim-4 landscape dim-5 mean
# dissim-4 landscape dim-5 sum
# dissim-4 landscape dim-5 norm-1
# dissim-4 silhouette-1 dim-1 median
# dissim-4 silhouette-1 dim-5 mean
# dissim-4 silhouette-1 dim-5 sum
# dissim-4 silhouette-1 dim-5 norm-1
# dissim-4 silhouette-2 dim-1 median
# dissim-4 silhouette-2 dim-5 mean
# dissim-4 silhouette-2 dim-5 sum
# dissim-4 silhouette-2 dim-5 norm-1
# dissim-4 entropy dim-1
# dissim-4 amplitude-bottleneck dim-5
# dissim-4 amplitude-landscape-1-1 dim-5
# dissim-4 amplitude-landscape-1-2 dim-5
# dissim-4 amplitude-silhouette-1-1 dim-5
# dissim-4 amplitude-silhouette-1-2 dim-5
# dissim-4 life dim-5 max
# dissim-4 bd2 dim-4 std
# dissim-5 landscape dim-1 median
# dissim-5 silhouette-1 dim-1 median
# dissim-5 silhouette-1 dim-5 mean
# dissim-5 silhouette-1 dim-5 sum
# dissim-5 silhouette-1 dim-5 norm-1
# dissim-5 silhouette-2 dim-1 median
# dissim-5 entropy dim-1
# dissim-5 amplitude-silhouette-1-1 dim-5
# dissim-6 landscape dim-5 mean
# dissim-6 landscape dim-5 sum
# dissim-6 landscape dim-5 norm-1
# dissim-6 silhouette-1 dim-1 median
# dissim-6 silhouette-2 dim-1 median
# dissim-6 entropy dim-1
# dissim-6 amplitude-landscape-1-1 dim-5
# dissim-7 entropy dim-1
# dissim-8 silhouette-1 dim-1 median
# dissim-8 silhouette-2 dim-1 median
# dissim-8 entropy dim-1
# dissim-9 landscape dim-5 mean
# dissim-9 landscape dim-5 sum
# dissim-9 landscape dim-5 norm-1
# dissim-9 silhouette-1 dim-5 mean
# dissim-9 silhouette-1 dim-5 sum
# dissim-9 silhouette-1 dim-5 norm-1
# dissim-9 silhouette-2 dim-1 median
# dissim-9 silhouette-2 dim-5 mean
# dissim-9 silhouette-2 dim-5 sum
# dissim-9 silhouette-2 dim-5 norm-1
# dissim-9 entropy dim-1
# dissim-9 amplitude-landscape-1-1 dim-5
# dissim-9 amplitude-landscape-1-2 dim-5
# dissim-9 amplitude-landscape-2-2 dim-5
# dissim-9 amplitude-silhouette-1-1 dim-5
# dissim-9 amplitude-silhouette-1-2 dim-5
# dissim-9 life dim-4 std
# dissim-9 bd2 dim-4 std
# dissim-10 landscape dim-5 mean
# dissim-10 landscape dim-5 sum
# dissim-10 landscape dim-5 norm-1
# dissim-10 silhouette-1 dim-1 median
# dissim-10 silhouette-1 dim-5 mean
# dissim-10 silhouette-1 dim-5 sum
# dissim-10 silhouette-1 dim-5 norm-1
# dissim-10 silhouette-1 dim-5 norm-2
# dissim-10 silhouette-2 dim-1 median
# dissim-10 silhouette-2 dim-5 mean
# dissim-10 silhouette-2 dim-5 sum
# dissim-10 silhouette-2 dim-5 norm-1
# dissim-10 entropy dim-1
# dissim-10 amplitude-wasserstein-1 dim-5
# dissim-10 amplitude-landscape-1-1 dim-5
# dissim-10 amplitude-landscape-1-2 dim-5
# dissim-10 amplitude-silhouette-1-1 dim-5
# dissim-10 amplitude-silhouette-1-2 dim-5
# dissim-10 amplitude-silhouette-2-1 dim-5
# dissim-10 life dim-5 sum
# dissim-10 life dim-5 norm-1
# dissim-11 silhouette-1 dim-1 median
# dissim-11 entropy dim-1
# dissim-11 bd2 dim-4 std
# dissim-12 silhouette-1 dim-1 median
# dissim-12 silhouette-2 dim-1 median
# dissim-12 entropy dim-1
# dissim-13 silhouette-1 dim-1 median
# dissim-13 silhouette-2 dim-1 median
# dissim-13 silhouette-2 dim-5 mean
# dissim-13 silhouette-2 dim-5 sum
# dissim-13 silhouette-2 dim-5 norm-1
# dissim-13 entropy dim-1
# dissim-13 amplitude-silhouette-1-2 dim-5
# dissim-14 landscape dim-5 mean
# dissim-14 landscape dim-5 sum
# dissim-14 landscape dim-5 norm-1
# dissim-14 landscape dim-5 norm-2
# dissim-14 silhouette-1 dim-1 median
# dissim-14 silhouette-1 dim-2 kurtosis
# dissim-14 silhouette-1 dim-5 mean
# dissim-14 silhouette-1 dim-5 sum
# dissim-14 silhouette-1 dim-5 norm-1
# dissim-14 silhouette-2 dim-1 median
# dissim-14 silhouette-2 dim-5 mean
# dissim-14 silhouette-2 dim-5 std
# dissim-14 silhouette-2 dim-5 sum
# dissim-14 silhouette-2 dim-5 kurtosis
# dissim-14 silhouette-2 dim-5 norm-1
# dissim-14 silhouette-2 dim-5 norm-2
# dissim-14 entropy dim-1
# dissim-14 amplitude-landscape-1-1 dim-5
# dissim-14 amplitude-landscape-1-2 dim-5
# dissim-14 amplitude-landscape-2-1 dim-5
# dissim-14 amplitude-landscape-2-2 dim-5
# dissim-14 amplitude-silhouette-1-1 dim-5
# dissim-14 amplitude-silhouette-1-2 dim-5
# dissim-14 amplitude-silhouette-2-2 dim-5
# dissim-14 life dim-5 mean
# dissim-14 life dim-5 percentile-25
# dissim-14 life dim-5 median
# dissim-15 landscape dim-5 max
# dissim-15 landscape dim-5 mean
# dissim-15 landscape dim-5 std
# dissim-15 landscape dim-5 sum
# dissim-15 landscape dim-5 norm-1
# dissim-15 landscape dim-5 norm-2
# dissim-15 silhouette-1 dim-5 max
# dissim-15 silhouette-1 dim-5 mean
# dissim-15 silhouette-1 dim-5 std
# dissim-15 silhouette-1 dim-5 sum
# dissim-15 silhouette-1 dim-5 norm-1
# dissim-15 silhouette-1 dim-5 norm-2
# dissim-15 silhouette-2 dim-5 max
# dissim-15 silhouette-2 dim-5 mean
# dissim-15 silhouette-2 dim-5 std
# dissim-15 silhouette-2 dim-5 sum
# dissim-15 silhouette-2 dim-5 norm-1
# dissim-15 silhouette-2 dim-5 norm-2
# dissim-15 entropy dim-1
# dissim-15 amplitude-landscape-1-1 dim-5
# dissim-15 amplitude-landscape-1-2 dim-5
# dissim-15 amplitude-landscape-2-1 dim-5
# dissim-15 amplitude-landscape-2-2 dim-5
# dissim-15 amplitude-silhouette-1-1 dim-5
# dissim-15 amplitude-silhouette-1-2 dim-5
# dissim-15 amplitude-silhouette-2-1 dim-5
# dissim-15 amplitude-silhouette-2-2 dim-5
# dissim-16 silhouette-1 dim-1 median
# dissim-16 silhouette-2 dim-1 median
# dissim-16 silhouette-2 dim-5 std
# dissim-16 silhouette-2 dim-5 norm-2
# dissim-16 entropy dim-1
# dissim-16 amplitude-landscape-1-2 dim-5
# dissim-16 amplitude-silhouette-2-2 dim-5
# dissim-17 landscape dim-5 mean
# dissim-17 landscape dim-5 sum
# dissim-17 landscape dim-5 norm-1
# dissim-17 silhouette-1 dim-1 median
# dissim-17 silhouette-1 dim-5 mean
# dissim-17 silhouette-1 dim-5 sum
# dissim-17 silhouette-1 dim-5 norm-1
# dissim-17 silhouette-1 dim-5 norm-2
# dissim-17 silhouette-2 dim-1 median
# dissim-17 silhouette-2 dim-5 mean
# dissim-17 silhouette-2 dim-5 std
# dissim-17 silhouette-2 dim-5 sum
# dissim-17 silhouette-2 dim-5 norm-1
# dissim-17 silhouette-2 dim-5 norm-2
# dissim-17 entropy dim-1
# dissim-17 amplitude-landscape-1-1 dim-5
# dissim-17 amplitude-landscape-1-2 dim-5
# dissim-17 amplitude-silhouette-1-1 dim-5
# dissim-17 amplitude-silhouette-1-2 dim-5
# dissim-17 amplitude-silhouette-2-1 dim-5
# dissim-17 amplitude-silhouette-2-2 dim-5
# dissim-18 silhouette-1 dim-1 median
# dissim-18 silhouette-2 dim-1 median
# dissim-18 entropy dim-1
# dissim-19 silhouette-1 dim-1 median
# dissim-19 silhouette-2 dim-1 median
# dissim-19 entropy dim-1
# dissim-19 bd2 dim-2 percentile-75
# dissim-20 landscape dim-5 mean
# dissim-20 landscape dim-5 sum
# dissim-20 landscape dim-5 norm-1
# dissim-20 silhouette-1 dim-1 median
# dissim-20 silhouette-2 dim-1 median
# dissim-20 entropy dim-1
# dissim-20 amplitude-landscape-1-1 dim-5
# dissim-20 amplitude-landscape-1-2 dim-5
# dissim-20 amplitude-landscape-2-2 dim-5
# dissim-21 silhouette-1 dim-1 median
# dissim-21 silhouette-2 dim-1 median
# dissim-21 entropy dim-1
# dissim-22 landscape dim-4 mean
# dissim-22 landscape dim-4 sum
# dissim-22 landscape dim-4 norm-1
# dissim-22 silhouette-1 dim-1 median
# dissim-22 silhouette-1 dim-4 mean
# dissim-22 silhouette-1 dim-4 sum
# dissim-22 silhouette-1 dim-4 norm-1
# dissim-22 silhouette-2 dim-1 median
# dissim-22 entropy dim-1
# dissim-22 amplitude-landscape-1-1 dim-4
# dissim-22 amplitude-silhouette-1-1 dim-4
# dissim-23 landscape dim-1 median
# dissim-23 landscape dim-2 kurtosis
# dissim-23 landscape dim-5 mean
# dissim-23 landscape dim-5 sum
# dissim-23 landscape dim-5 norm-1
# dissim-23 landscape dim-5 norm-2
# dissim-23 silhouette-1 dim-1 median
# dissim-23 silhouette-1 dim-5 max
# dissim-23 silhouette-1 dim-5 mean
# dissim-23 silhouette-1 dim-5 std
# dissim-23 silhouette-1 dim-5 sum
# dissim-23 silhouette-1 dim-5 norm-1
# dissim-23 silhouette-1 dim-5 norm-2
# dissim-23 silhouette-2 dim-1 median
# dissim-23 silhouette-2 dim-5 mean
# dissim-23 silhouette-2 dim-5 std
# dissim-23 silhouette-2 dim-5 sum
# dissim-23 silhouette-2 dim-5 norm-1
# dissim-23 silhouette-2 dim-5 norm-2
# dissim-23 entropy dim-1
# dissim-23 amplitude-landscape-1-1 dim-5
# dissim-23 amplitude-landscape-1-2 dim-5
# dissim-23 amplitude-landscape-2-1 dim-5
# dissim-23 amplitude-silhouette-1-1 dim-5
# dissim-23 amplitude-silhouette-1-2 dim-5
# dissim-23 amplitude-silhouette-2-1 dim-5
# dissim-23 amplitude-silhouette-2-2 dim-5
# dissim-23 life dim-4 std
# Missed 269 features

# %%
validate("Subj3")
# Out:
# dissim-0 landscape dim-1 median
# dissim-0 silhouette-1 dim-1 median
# dissim-0 silhouette-2 dim-1 median
# dissim-0 entropy dim-1
# dissim-0 bd2 dim-3 std
# dissim-1 silhouette-1 dim-1 median
# dissim-1 silhouette-2 dim-1 median
# dissim-1 entropy dim-1
# dissim-2 silhouette-1 dim-1 median
# dissim-2 entropy dim-1
# dissim-3 silhouette-1 dim-1 median
# dissim-3 silhouette-2 dim-1 median
# dissim-3 entropy dim-1
# dissim-4 silhouette-1 dim-1 median
# dissim-4 silhouette-2 dim-1 median
# dissim-4 amplitude-landscape-1-2 dim-4
# dissim-5 landscape dim-4 mean
# dissim-5 landscape dim-4 sum
# dissim-5 landscape dim-4 norm-1
# dissim-5 silhouette-1 dim-1 median
# dissim-5 silhouette-2 dim-1 median
# dissim-5 entropy dim-1
# dissim-5 amplitude-landscape-1-1 dim-4
# dissim-5 bd2 dim-3 std
# dissim-6 landscape dim-1 median
# dissim-6 silhouette-1 dim-1 median
# dissim-6 silhouette-2 dim-1 median
# dissim-6 entropy dim-1
# dissim-7 landscape dim-1 median
# dissim-7 landscape dim-4 mean
# dissim-7 landscape dim-4 sum
# dissim-7 landscape dim-4 norm-1
# dissim-7 silhouette-1 dim-1 median
# dissim-7 silhouette-1 dim-4 mean
# dissim-7 silhouette-1 dim-4 sum
# dissim-7 silhouette-1 dim-4 norm-1
# dissim-7 silhouette-2 dim-1 median
# dissim-7 silhouette-2 dim-4 std
# dissim-7 entropy dim-1
# dissim-7 amplitude-landscape-1-1 dim-4
# dissim-7 amplitude-landscape-1-2 dim-4
# dissim-7 amplitude-silhouette-1-1 dim-4
# dissim-8 landscape dim-1 median
# dissim-8 silhouette-1 dim-1 median
# dissim-8 silhouette-2 dim-1 median
# dissim-8 entropy dim-1
# dissim-9 landscape dim-1 median
# dissim-9 silhouette-1 dim-1 median
# dissim-9 silhouette-2 dim-1 median
# dissim-9 entropy dim-1
# dissim-10 landscape dim-1 median
# dissim-10 silhouette-1 dim-1 median
# dissim-10 silhouette-2 dim-1 median
# dissim-11 landscape dim-1 median
# dissim-11 landscape dim-4 mean
# dissim-11 landscape dim-4 sum
# dissim-11 landscape dim-4 norm-1
# dissim-11 silhouette-1 dim-1 median
# dissim-11 silhouette-1 dim-4 mean
# dissim-11 silhouette-1 dim-4 sum
# dissim-11 silhouette-1 dim-4 norm-1
# dissim-11 silhouette-2 dim-1 median
# dissim-11 entropy dim-1
# dissim-11 amplitude-landscape-1-1 dim-4
# dissim-11 amplitude-silhouette-1-1 dim-4
# dissim-12 landscape dim-1 median
# dissim-12 silhouette-1 dim-1 median
# dissim-12 silhouette-2 dim-1 median
# dissim-12 entropy dim-1
# dissim-13 landscape dim-1 median
# dissim-13 landscape dim-4 mean
# dissim-13 landscape dim-4 sum
# dissim-13 landscape dim-4 norm-1
# dissim-13 silhouette-1 dim-1 median
# dissim-13 silhouette-1 dim-3 mean
# dissim-13 silhouette-1 dim-3 sum
# dissim-13 silhouette-1 dim-3 norm-1
# dissim-13 silhouette-2 dim-1 median
# dissim-13 entropy dim-1
# dissim-13 amplitude-landscape-1-1 dim-4
# dissim-13 amplitude-silhouette-1-1 dim-3
# dissim-14 landscape dim-1 median
# dissim-14 silhouette-1 dim-1 median
# dissim-14 silhouette-2 dim-1 median
# dissim-14 entropy dim-1
# dissim-15 landscape dim-4 std
# dissim-15 landscape dim-4 norm-2
# dissim-15 silhouette-1 dim-1 median
# dissim-15 silhouette-2 dim-1 median
# dissim-15 silhouette-2 dim-4 mean
# dissim-15 silhouette-2 dim-4 std
# dissim-15 silhouette-2 dim-4 sum
# dissim-15 silhouette-2 dim-4 norm-1
# dissim-15 entropy dim-1
# dissim-15 amplitude-landscape-1-2 dim-4
# dissim-15 amplitude-landscape-2-1 dim-4
# dissim-15 amplitude-silhouette-1-2 dim-4
# dissim-16 landscape dim-1 median
# dissim-16 landscape dim-3 mean
# dissim-16 landscape dim-3 sum
# dissim-16 landscape dim-3 norm-1
# dissim-16 silhouette-1 dim-1 median
# dissim-16 silhouette-2 dim-1 median
# dissim-16 silhouette-2 dim-3 mean
# dissim-16 silhouette-2 dim-3 sum
# dissim-16 silhouette-2 dim-3 norm-1
# dissim-16 entropy dim-1
# dissim-16 amplitude-landscape-1-1 dim-3
# dissim-16 amplitude-silhouette-1-2 dim-3
# dissim-16 bd2 dim-3 std
# dissim-17 landscape dim-1 median
# dissim-17 silhouette-1 dim-1 median
# dissim-17 silhouette-2 dim-1 median
# dissim-17 entropy dim-1
# dissim-17 life dim-3 std
# dissim-18 landscape dim-1 median
# dissim-18 silhouette-1 dim-1 median
# dissim-18 silhouette-1 dim-4 mean
# dissim-18 silhouette-1 dim-4 sum
# dissim-18 silhouette-1 dim-4 norm-1
# dissim-18 silhouette-2 dim-1 median
# dissim-18 amplitude-silhouette-1-1 dim-4
# dissim-19 landscape dim-1 median
# dissim-19 silhouette-1 dim-1 median
# dissim-19 silhouette-2 dim-1 median
# dissim-19 entropy dim-1
# dissim-19 amplitude-landscape-1-2 dim-4
# dissim-20 silhouette-1 dim-1 median
# dissim-20 silhouette-2 dim-1 median
# dissim-20 entropy dim-1
# dissim-21 landscape dim-1 median
# dissim-21 landscape dim-4 mean
# dissim-21 landscape dim-4 sum
# dissim-21 landscape dim-4 norm-1
# dissim-21 silhouette-1 dim-1 median
# dissim-21 silhouette-2 dim-1 median
# dissim-21 entropy dim-1
# dissim-21 amplitude-landscape-1-1 dim-4
# dissim-21 life dim-1 percentile-25
# dissim-21 bd2 dim-3 std
# dissim-22 landscape dim-1 median
# dissim-22 silhouette-1 dim-1 median
# dissim-22 silhouette-2 dim-1 median
# dissim-22 entropy dim-1
# dissim-22 bd2 dim-3 std
# dissim-23 landscape dim-1 median
# dissim-23 silhouette-1 dim-1 median
# dissim-23 silhouette-2 dim-1 median
# dissim-23 amplitude-landscape-1-2 dim-4
# dissim-23 amplitude-landscape-2-2 dim-4
# dissim-23 bd2 dim-3 std
# dissim-23 bd2 dim-4 sum
# dissim-23 bd2 dim-4 norm-1
# Missed 153 features

# %% [markdown]
# ### IV

# %%
def construct_joint_iv():
    scores1 = pandas.read_csv("Subj1/exp_full_flow/iv/iv.csv")
    scores2 = pandas.read_csv("Subj2/exp_full_flow/iv/iv.csv")
    scores3 = pandas.read_csv("Subj3/exp_full_flow/iv/iv.csv")
    
    scores = scores1.join(scores2, lsuffix = "_subj1", rsuffix = "_subj2").join(scores3, rsuffix = "_subj3")
    scores = scores[["Feature_subj1", "IV_subj1", "IV_subj2", "IV" ]]
    scores = scores.rename(columns = { 'Feature_subj1': 'name', 'IV_subj1': 'subj1', 'IV_subj2': 'subj2', 'IV': 'subj3' })

    return scores

# %%
def filter1(scores):
    scores = scores[scores["Stat"] != "percentile-25"]
    scores = scores[scores["Stat"] != "median"]
    scores = scores[scores["Stat"] != "percentile-75"]
    scores = scores[scores["Stat"] != "skew"]
    scores = scores[scores["Stat"] != "kurtosis"]
    return scores

display(analyze(construct_joint_iv(), by = 'Stat'))
display(analyze(construct_joint_iv(), by = 'Stat', filters = [ filter1 ]))

# %%
def filter2(scores):
    scores = scores[scores["Dimension"] != "all"]
    scores = scores[scores["Dimension"] != "dim-4"]
    scores = scores[scores["Dimension"] != "dim-5"]
    return scores

display(analyze(construct_joint_iv(), by = 'Dimension', filters = [ filter1 ]))
display(analyze(construct_joint_iv(), by = 'Dimension', filters = [ filter1, filter2 ]))

# %%
def filter3(scores):
    scores = scores[scores["Algorithm"] != "betti"]
    scores = scores[scores["Algorithm"] != "numberofpoints"]
    scores = scores[scores["Algorithm"] != "amplitude-betti-1"]
    scores = scores[scores["Algorithm"] != "amplitude-betti-2"]
    return scores

display(analyze(construct_joint_iv(), by = 'Algorithm', filters = [ filter1, filter2 ]))
display(analyze(construct_joint_iv(), by = 'Algorithm', filters = [ filter1, filter2, filter3 ]))

# %%
def filter4(scores):
    for source in numpy.unique(scores["Source"]):
        if source.startswith("dissim"):
            scores = scores[scores["Source"] != source]
    return scores

display(analyze(construct_joint_iv(), by = 'Source', filters = [ filter1, filter2, filter3, filter4 ]).head(60))
