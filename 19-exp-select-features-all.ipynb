# %%
import os

subj = "Subj1"
N_STAGES = 9

N_SELECTION_STAGES = 5
RERUN = False

exp = "exp_select_features_all"
features_type = 'exp_final_filtered'
os.makedirs(f"{subj}/{exp}", exist_ok = True)

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

import SDA
import SDA.analytics
import SDA.clustquality

import umap
import tqdm
import numpy
import pandas
import joblib
import sklearn.metrics
import sklearn.preprocessing
import sklearn.decomposition
import tqdm.contrib.itertools
import matplotlib.pyplot as plt
import sklearn.feature_selection
import sklearn.cross_decomposition
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def explained_variance(features, reduced):
    pls = sklearn.cross_decomposition.PLSRegression(n_components = reduced.shape[1])
    y_pred = pls.fit(reduced, features).predict(reduced)
    return sklearn.metrics.r2_score(features, y_pred, multioutput = "variance_weighted")

# %% [markdown]
# ### Selection

# %%
edges_true = numpy.loadtxt(f"{subj}/reproduction/internal/best_edges.txt").astype(numpy.int32)
df_features = pandas.read_feather(f'{subj}/{features_type}/all_features.feather')
print(df_features.shape)

features = sklearn.preprocessing.StandardScaler().fit_transform(df_features)
print(features.shape)

params = {
    'n_clusters_min': 2, 'n_clusters_max': 8,
    'k_neighbours': range(20, 51, 3),
    'len_st_thr': [ 40 ],

    'n_cl_max_thr': [ 20 ],
    'k_neighb_max_thr': [ 50 ],
    'n_edge_clusters_min': N_SELECTION_STAGES - 1, 'n_edge_clusters_max': N_SELECTION_STAGES - 1
}
# Out:
# (1046, 3799)
# (1046, 3799)

# %%
def score_feature(i: int):
    try:
        result, _ = SDA.SDA(**params, n_jobs = 1, scale = False, verbose = False).apply(features[:, i].reshape(-1, 1))
        result = SDA.analytics.best_result(result, key = 'Avg-Silh', n_stages = N_SELECTION_STAGES)
        if len(result['St_edges']) != N_SELECTION_STAGES + 1:
            raise RuntimeError()
        score = result['Avg-Silh']
    except:
        score = -1
    source_feature = df_features[df_features.columns[i]]
    edges = numpy.array(result['St_edges'] if score != -1 else [])
    return {
        'index': i,
        'name': df_features.columns[i],
        'score': score,
        'mean': source_feature.mean(),
        'variance': source_feature.var(),
        'unique_values': len(numpy.unique(features[:, i])),
        'edges': result['St_edges'] if score != -1 else None,
        'min_stage_length': (edges[1:] - edges[:-1]).min() if score != -1 else None
    }

# %%
if RERUN:
    scores = joblib.Parallel(n_jobs = 14)(joblib.delayed(score_feature)(i) for i in tqdm.trange(features.shape[1]))
    scores = pandas.DataFrame(list(scores))
else:
    scores = pandas.read_csv(f"{subj}/{exp}/scores_{features_type[4:]}.csv")
display(scores)
# Out:
#       index                                  name     score       mean  \
# 0         0               channel-0 entropy dim-1  0.250481  -0.381905
# 1         1               channel-0 entropy dim-2  0.100504  -0.135152
# 2         2        channel-0 numberofpoints dim-1  0.209758  62.464627
# 3         3        channel-0 numberofpoints dim-2  0.104908   8.312620
# 4         4  channel-0 amplitude-bottleneck dim-1  0.195806   0.000004
# ...     ...                                   ...       ...        ...
# 3794   3794                overall bd2 dim-3 mean  0.059686   0.000094
# 3795   3795                 overall bd2 dim-3 std  0.020077   0.000006
# 3796   3796                 overall bd2 dim-3 sum  0.045086   0.000429
# 3797   3797              overall bd2 dim-3 norm-1  0.045086   0.000429
# 3798   3798              overall bd2 dim-3 norm-2  0.050174   0.000190
#
#           variance  unique_values                          edges  \
# 0     1.793640e-03           1046   [0, 65, 246, 556, 659, 1046]
# 1     2.854760e-03           1024  [0, 105, 588, 821, 971, 1046]
# 2     1.683160e+02             72   [0, 98, 238, 550, 650, 1046]
# 3     2.473758e+01             35  [0, 136, 585, 823, 975, 1046]
# 4     6.940859e-12           1046   [0, 50, 512, 556, 647, 1046]
# ...            ...            ...                            ...
# 3794  2.766734e-09            861   [0, 82, 357, 552, 777, 1046]
# 3795  7.849244e-11            700  [0, 113, 278, 553, 799, 1046]
# 3796  2.310777e-07            861  [0, 110, 313, 526, 804, 1046]
# 3797  2.310777e-07            861  [0, 110, 313, 526, 804, 1046]
# 3798  2.183351e-08            861  [0, 104, 554, 686, 855, 1046]
#
#       min_stage_length
# 0                 65.0
# 1                 75.0
# 2                 98.0
# 3                 71.0
# 4                 44.0
# ...                ...
# 3794              82.0
# 3795             113.0
# 3796             110.0
# 3797             110.0
# 3798             104.0
#
# [3799 rows x 8 columns]

# %%
scores.to_csv(f"{subj}/{exp}/scores_{features_type[4:]}.csv", index = False)
display(scores.sort_values(by = 'score', ascending = False))
# Out:
#       index                                        name     score  \
# 2617   2617   channel-28 amplitude-silhouette-1-1 dim-2  0.629530
# 2341   2341   channel-25 amplitude-silhouette-1-1 dim-2  0.539729
# 2625   2625   channel-28 amplitude-silhouette-2-1 dim-2  0.534404
# 2347   2347  channel-25 amplitude-silhouette-1-2 norm-2  0.520269
# 2621   2621   channel-28 amplitude-silhouette-1-2 dim-2  0.520216
# ...     ...                                         ...       ...
# 1056   1056   channel-11 amplitude-silhouette-1-2 dim-1 -1.000000
# 1058   1058  channel-11 amplitude-silhouette-1-2 norm-1 -1.000000
# 1059   1059  channel-11 amplitude-silhouette-1-2 norm-2 -1.000000
# 2249   2249   channel-24 amplitude-silhouette-1-1 dim-2 -1.000000
# 1036   1036    channel-11 amplitude-landscape-1-1 dim-1 -1.000000
#
#               mean      variance  unique_values  \
# 2617  1.546327e-13  2.071976e-25           1012
# 2341  1.384475e-13  3.523781e-25            955
# 2625  1.201888e-10  6.708030e-20           1012
# 2347  2.629310e-12  1.966975e-22           1046
# 2621  2.070312e-13  3.000437e-25           1012
# ...            ...           ...            ...
# 1056  4.903853e-12  2.184737e-22           1046
# 1058  5.160625e-12  2.199826e-22           1046
# 1059  4.934292e-12  2.183998e-22           1046
# 2249  6.774115e-14  1.656250e-26           1002
# 1036  1.160287e-11  4.062054e-22           1046
#
#                               edges  min_stage_length
# 2617  [0, 266, 272, 322, 332, 1046]               6.0
# 2341  [0, 124, 179, 711, 768, 1046]              55.0
# 2625  [0, 266, 272, 310, 332, 1046]               6.0
# 2347  [0, 141, 183, 691, 790, 1046]              42.0
# 2621  [0, 250, 266, 272, 332, 1046]               6.0
# ...                             ...               ...
# 1056                            NaN               NaN
# 1058                            NaN               NaN
# 1059                            NaN               NaN
# 2249                            NaN               NaN
# 1036                            NaN               NaN
#
# [3799 rows x 8 columns]

# %%
NUM_FEATURES = 765
MIN_STAGE_LENGTH = 40
CORR_THRESHOLD = 0.99
MIN_UNIQUE_VALUES = 20

best_feature_keys = numpy.empty(0,)
best_features = numpy.empty((features.shape[0], 0))
for i, (idx, row) in enumerate(scores.sort_values(by = 'score', ascending = False).iterrows()):
    if row['unique_values'] < MIN_UNIQUE_VALUES:
        print(f'{i + 1}. {row["name"]} - SKIP (unique_values = {row["unique_values"]})')
        continue
    if row['min_stage_length'] < MIN_STAGE_LENGTH:
        print(f'{i + 1}. {row["name"]} - SKIP (min_stage_length = {row["min_stage_length"]})')
        continue

    key = row["name"].split(' ', 1)[0]
    feature = features[:, row['index']].reshape(-1, 1)

    same_key = best_features[:, best_feature_keys == key]
    if same_key.shape[1] != 0:
        for_corrs = numpy.concatenate((same_key, feature), axis = 1)
        corrs = numpy.corrcoef(for_corrs.T)[-1, :-1]
        max_corr = numpy.max(numpy.abs(corrs))
        if max_corr > CORR_THRESHOLD:
            print(f'{i + 1}. {row["name"]} - SKIP (max_corr = {max_corr})')
            continue

    best_features = numpy.concatenate((best_features, feature), axis = 1)
    best_feature_keys = numpy.append(best_feature_keys, key)
    print(f'{i + 1}. {row["name"]} - OK')
    if best_features.shape[1] == NUM_FEATURES:
        break

print(best_features.shape)
print(numpy.unique(best_feature_keys, return_counts = True))
# Out:
# 1. channel-28 amplitude-silhouette-1-1 dim-2 - SKIP (min_stage_length = 6.0)
# 2. channel-25 amplitude-silhouette-1-1 dim-2 - OK
# 3. channel-28 amplitude-silhouette-2-1 dim-2 - SKIP (min_stage_length = 6.0)
# 4. channel-25 amplitude-silhouette-1-2 norm-2 - OK
# 5. channel-28 amplitude-silhouette-1-2 dim-2 - SKIP (min_stage_length = 6.0)
# 6. channel-25 amplitude-silhouette-1-1 norm-2 - SKIP (max_corr = 0.9956076954121463)
# 7. channel-25 amplitude-silhouette-1-1 dim-1 - SKIP (max_corr = 0.9954615657848307)
# 8. channel-25 amplitude-silhouette-1-1 norm-1 - SKIP (max_corr = 0.995021316811561)
# 9. channel-25 amplitude-landscape-1-1 dim-1 - OK
# 10. channel-25 amplitude-landscape-1-1 norm-2 - SKIP (max_corr = 0.9999085155774673)
# 11. channel-25 amplitude-silhouette-1-2 dim-2 - SKIP (max_corr = 0.9937187415085188)
# 12. channel-25 amplitude-silhouette-1-2 dim-1 - SKIP (max_corr = 0.9997036548511935)
# 13. channel-25 amplitude-landscape-1-1 dim-2 - OK
# 14. channel-25 amplitude-silhouette-2-2 dim-1 - OK
# 15. channel-25 amplitude-silhouette-2-1 dim-1 - OK
# 16. channel-25 amplitude-landscape-2-2 dim-1 - OK
# 17. channel-26 amplitude-landscape-1-2 dim-2 - OK
# 18. channel-25 amplitude-landscape-1-2 dim-1 - OK
# 19. channel-26 bd2 dim-1 sum - OK
# 20. channel-26 bd2 dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 21. channel-26 bd2 dim-1 norm-2 - OK
# 22. channel-12 bd2 dim-1 norm-2 - OK
# 23. channel-25 amplitude-landscape-1-2 norm-1 - SKIP (max_corr = 0.9989825747333204)
# 24. channel-26 amplitude-landscape-1-1 dim-2 - SKIP (max_corr = 0.9992019538228638)
# 25. channel-26 amplitude-silhouette-1-2 norm-2 - OK
# 26. channel-26 amplitude-betti-1 norm-2 - OK
# 27. channel-26 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.999990744264413)
# 28. channel-26 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.9964488356198821)
# 29. channel-26 bd2 all norm-2 - OK
# 30. channel-26 life dim-1 norm-1 - SKIP (max_corr = 0.9915244534074249)
# 31. channel-26 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9915244534074249)
# 32. channel-26 life dim-1 sum - SKIP (max_corr = 0.9915244534074249)
# 33. channel-25 amplitude-landscape-1-2 norm-2 - SKIP (max_corr = 0.9999685564473779)
# 34. channel-26 life all sum - OK
# 35. channel-26 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 1.0)
# 36. channel-26 life all norm-1 - SKIP (max_corr = 1.0)
# 37. channel-26 bd2 all sum - OK
# 38. channel-26 bd2 all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 39. channel-25 amplitude-silhouette-2-1 norm-2 - SKIP (max_corr = 0.9945511536551486)
# 40. channel-26 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9980573262097229)
# 41. channel-26 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9981870368761033)
# 42. channel-25 amplitude-landscape-1-2 dim-2 - SKIP (max_corr = 0.9906912656848874)
# 43. channel-25 amplitude-silhouette-2-1 norm-1 - OK
# 44. channel-25 amplitude-silhouette-2-2 norm-1 - SKIP (max_corr = 0.9920596339372264)
# 45. channel-2 amplitude-silhouette-1-2 dim-1 - SKIP (min_stage_length = 10.0)
# 46. channel-2 amplitude-silhouette-1-2 norm-2 - SKIP (min_stage_length = 10.0)
# 47. channel-25 amplitude-landscape-2-2 norm-1 - SKIP (max_corr = 0.9942031754236618)
# 48. channel-12 bd2 all norm-2 - SKIP (max_corr = 0.9958256556729359)
# 49. channel-25 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9935779107970673)
# 50. channel-12 amplitude-silhouette-1-1 norm-2 - SKIP (min_stage_length = 28.0)
# 51. channel-31 amplitude-betti-1 norm-2 - OK
# 52. channel-31 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9999914554334197)
# 53. channel-12 bd2 dim-1 norm-1 - OK
# 54. channel-12 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 55. channel-12 bd2 dim-1 mean - OK
# 56. channel-26 amplitude-wasserstein-2 dim-1 - OK
# 57. channel-26 life dim-1 norm-2 - SKIP (max_corr = 0.9999999999999998)
# 58. channel-11 bd2 all norm-2 - OK
# 59. channel-26 life all norm-2 - SKIP (max_corr = 0.9988735147481067)
# 60. channel-26 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9988735147481067)
# 61. channel-31 bd2 all norm-2 - OK
# 62. channel-25 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9996498756514225)
# 63. channel-13 amplitude-silhouette-1-2 dim-2 - SKIP (min_stage_length = 6.0)
# 64. channel-26 life dim-2 mean - OK
# 65. channel-26 amplitude-wasserstein-2 norm-1 - OK
# 66. channel-31 bd2 dim-1 norm-2 - OK
# 67. channel-7 amplitude-silhouette-1-2 dim-1 - OK
# 68. channel-11 bd2 dim-1 norm-2 - SKIP (max_corr = 0.9936953646692452)
# 69. channel-25 amplitude-silhouette-2-1 dim-2 - OK
# 70. channel-26 bd2 dim-1 mean - OK
# 71. channel-25 amplitude-landscape-2-2 dim-2 - OK
# 72. channel-7 amplitude-silhouette-1-2 norm-2 - SKIP (max_corr = 0.9997655316895584)
# 73. overall bd2 all norm-2 - OK
# 74. channel-0 amplitude-silhouette-2-2 norm-2 - SKIP (min_stage_length = 3.0)
# 75. channel-26 bd2 all mean - SKIP (max_corr = 0.9945030426703021)
# 76. channel-6 bd2 dim-1 mean - OK
# 77. channel-7 bd2 all norm-2 - OK
# 78. channel-11 bd2 dim-1 mean - OK
# 79. channel-12 bd2 all norm-1 - SKIP (max_corr = 0.9936943093973452)
# 80. channel-12 bd2 all sum - SKIP (max_corr = 0.9936943093973452)
# 81. channel-32 bd2 dim-1 norm-2 - OK
# 82. channel-25 bd2 all norm-2 - OK
# 83. channel-30 bd2 dim-1 norm-2 - OK
# 84. channel-11 bd2 all sum - OK
# 85. channel-11 bd2 all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 86. channel-11 amplitude-silhouette-1-1 dim-1 - OK
# 87. channel-25 bd2 dim-1 sum - OK
# 88. channel-25 bd2 dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 89. channel-13 amplitude-silhouette-1-1 dim-2 - SKIP (min_stage_length = 23.0)
# 90. channel-31 bd2 dim-1 mean - OK
# 91. channel-1 amplitude-landscape-2-1 norm-2 - OK
# 92. channel-26 amplitude-silhouette-1-1 dim-1 - OK
# 93. channel-32 bd2 all norm-2 - OK
# 94. channel-6 bd2 dim-1 norm-2 - OK
# 95. channel-0 amplitude-landscape-1-2 norm-1 - OK
# 96. channel-26 amplitude-landscape-2-1 norm-2 - OK
# 97. channel-26 amplitude-landscape-2-1 dim-1 - SKIP (min_stage_length = 36.0)
# 98. channel-12 bd2 dim-2 norm-2 - SKIP (min_stage_length = 31.0)
# 99. channel-1 amplitude-landscape-1-2 dim-1 - OK
# 100. channel-1 amplitude-landscape-1-2 norm-2 - SKIP (max_corr = 0.9999908863201329)
# 101. channel-26 amplitude-landscape-2-2 norm-1 - OK
# 102. channel-26 amplitude-landscape-2-1 dim-2 - OK
# 103. channel-7 bd2 dim-1 sum - OK
# 104. channel-7 bd2 dim-1 norm-1 - SKIP (max_corr = 1.0)
# 105. channel-11 amplitude-silhouette-1-1 norm-1 - SKIP (max_corr = 0.9983102973255464)
# 106. channel-25 amplitude-wasserstein-1 dim-1 - OK
# 107. channel-25 life dim-1 sum - SKIP (max_corr = 1.0)
# 108. channel-25 life dim-1 norm-1 - SKIP (max_corr = 1.0)
# 109. channel-1 amplitude-silhouette-1-2 dim-1 - SKIP (min_stage_length = 34.0)
# 110. channel-25 life all sum - SKIP (max_corr = 0.9969828567264333)
# 111. channel-25 life all norm-1 - SKIP (max_corr = 0.9969828567264333)
# 112. channel-25 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9969828567264333)
# 113. channel-25 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9999834837704388)
# 114. channel-6 bd2 dim-1 norm-1 - OK
# 115. channel-6 bd2 dim-1 sum - SKIP (max_corr = 1.0)
# 116. channel-12 bd2 all mean - SKIP (max_corr = 0.9986759395243165)
# 117. channel-12 amplitude-silhouette-1-2 norm-1 - OK
# 118. channel-26 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9920664289732494)
# 119. channel-0 amplitude-landscape-2-2 norm-1 - OK
# 120. channel-1 amplitude-silhouette-1-2 norm-2 - SKIP (min_stage_length = 34.0)
# 121. channel-1 amplitude-silhouette-1-2 norm-1 - SKIP (min_stage_length = 34.0)
# 122. channel-6 bd2 all norm-2 - SKIP (max_corr = 0.9929102487490598)
# 123. channel-12 bd2 dim-2 mean - OK
# 124. channel-26 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9943396143559904)
# 125. channel-26 amplitude-bottleneck dim-2 - OK
# 126. channel-26 life dim-2 max - SKIP (max_corr = 1.0)
# 127. channel-12 amplitude-landscape-1-1 norm-1 - OK
# 128. channel-11 bd2 all mean - SKIP (max_corr = 0.9984886841125518)
# 129. channel-6 bd2 all mean - SKIP (max_corr = 0.9985592465173783)
# 130. channel-26 life dim-2 std - OK
# 131. channel-32 bd2 dim-1 norm-1 - OK
# 132. channel-32 bd2 dim-1 sum - SKIP (max_corr = 1.0)
# 133. channel-26 amplitude-landscape-1-2 norm-2 - OK
# 134. channel-30 bd2 dim-1 norm-1 - OK
# 135. channel-30 bd2 dim-1 sum - SKIP (max_corr = 1.0)
# 136. channel-26 amplitude-landscape-2-2 dim-2 - SKIP (max_corr = 0.999772022385595)
# 137. channel-7 bd2 dim-1 norm-2 - SKIP (max_corr = 0.9919433990349595)
# 138. channel-26 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.9997162777034988)
# 139. channel-26 amplitude-landscape-1-2 norm-1 - SKIP (max_corr = 0.9976618862886181)
# 140. channel-12 amplitude-landscape-1-1 dim-1 - SKIP (min_stage_length = 28.0)
# 141. channel-26 amplitude-silhouette-2-2 dim-2 - SKIP (max_corr = 0.9909841161231581)
# 142. channel-12 amplitude-landscape-1-1 norm-2 - SKIP (min_stage_length = 28.0)
# 143. channel-26 amplitude-bottleneck norm-1 - OK
# 144. channel-26 amplitude-landscape-1-1 dim-1 - OK
# 145. channel-2 amplitude-silhouette-2-1 norm-1 - OK
# 146. channel-31 bd2 dim-1 sum - OK
# 147. channel-31 bd2 dim-1 norm-1 - SKIP (max_corr = 1.0)
# 148. channel-25 amplitude-betti-1 dim-1 - OK
# 149. channel-25 amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9999754828839891)
# 150. channel-26 amplitude-bottleneck norm-2 - OK
# 151. channel-32 life dim-1 sum - OK
# 152. channel-32 life dim-1 norm-1 - SKIP (max_corr = 1.0)
# 153. channel-32 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 1.0)
# 154. channel-32 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9999934698829868)
# 155. channel-26 amplitude-silhouette-2-2 norm-1 - OK
# 156. channel-26 bd2 all max - OK
# 157. channel-25 bd2 all norm-1 - OK
# 158. channel-25 bd2 all sum - SKIP (max_corr = 1.0)
# 159. channel-31 bd2 all mean - SKIP (max_corr = 0.9959373568543053)
# 160. channel-30 amplitude-betti-1 dim-1 - OK
# 161. channel-32 bd2 all sum - OK
# 162. channel-32 bd2 all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 163. channel-11 bd2 dim-1 norm-1 - OK
# 164. channel-11 bd2 dim-1 sum - SKIP (max_corr = 1.0)
# 165. channel-25 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9963256378074989)
# 166. channel-32 life all sum - SKIP (max_corr = 0.9977568260558182)
# 167. channel-32 life all norm-1 - SKIP (max_corr = 0.9977568260558182)
# 168. channel-32 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9977568260558182)
# 169. channel-7 bd2 all norm-1 - OK
# 170. channel-7 bd2 all sum - SKIP (max_corr = 1.0)
# 171. channel-9 bd2 all sum - OK
# 172. channel-9 bd2 all norm-1 - SKIP (max_corr = 1.0)
# 173. overall amplitude-wasserstein-1 norm-1 - OK
# 174. overall life all sum - SKIP (max_corr = 1.0)
# 175. overall life all norm-1 - SKIP (max_corr = 1.0)
# 176. channel-25 amplitude-wasserstein-2 norm-2 - OK
# 177. channel-25 life all norm-2 - SKIP (max_corr = 1.0)
# 178. channel-32 amplitude-betti-1 norm-2 - OK
# 179. channel-6 bd2 all norm-1 - SKIP (min_stage_length = 34.0)
# 180. channel-6 bd2 all sum - SKIP (min_stage_length = 34.0)
# 181. channel-26 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9939589697720661)
# 182. channel-30 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9956227893112554)
# 183. overall bd2 dim-1 norm-2 - OK
# 184. overall bd2 dim-1 sum - OK
# 185. overall bd2 dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 186. channel-26 amplitude-landscape-1-1 norm-2 - SKIP (max_corr = 0.9991302649273242)
# 187. channel-26 amplitude-silhouette-2-2 dim-1 - OK
# 188. channel-26 bd2 dim-2 max - OK
# 189. channel-6 amplitude-wasserstein-1 dim-1 - OK
# 190. channel-6 life dim-1 norm-1 - SKIP (max_corr = 1.0)
# 191. channel-6 life dim-1 sum - SKIP (max_corr = 1.0)
# 192. channel-26 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9956298845678748)
# 193. channel-26 life dim-1 max - SKIP (max_corr = 0.9956298845678748)
# 194. channel-31 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9904882175036158)
# 195. channel-1 amplitude-landscape-1-2 norm-1 - SKIP (max_corr = 0.9991497339607062)
# 196. channel-12 bd2 all std - OK
# 197. channel-25 amplitude-wasserstein-2 norm-1 - SKIP (max_corr = 0.9918998872963101)
# 198. channel-22 amplitude-silhouette-2-1 dim-2 - OK
# 199. channel-2 amplitude-landscape-2-1 norm-2 - OK
# 200. channel-2 amplitude-landscape-2-1 dim-1 - SKIP (max_corr = 0.9999438361730312)
# 201. channel-32 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9976072360417679)
# 202. channel-16 bd2 dim-1 norm-1 - OK
# 203. channel-16 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 204. channel-6 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9998699094151958)
# 205. channel-26 bd2 dim-2 norm-2 - OK
# 206. channel-11 amplitude-betti-1 dim-1 - OK
# 207. channel-12 bd2 dim-2 sum - OK
# 208. channel-12 bd2 dim-2 norm-1 - SKIP (max_corr = 1.0)
# 209. channel-13 amplitude-landscape-1-1 dim-2 - OK
# 210. channel-23 amplitude-silhouette-1-2 norm-1 - OK
# 211. channel-31 bd2 all sum - OK
# 212. channel-31 bd2 all norm-1 - SKIP (max_corr = 1.0)
# 213. channel-6 amplitude-wasserstein-2 norm-1 - OK
# 214. channel-25 amplitude-landscape-1-1 norm-1 - SKIP (max_corr = 0.998882322033133)
# 215. channel-28 amplitude-silhouette-2-2 dim-2 - OK
# 216. channel-1 amplitude-silhouette-2-2 norm-1 - SKIP (min_stage_length = 34.0)
# 217. channel-31 amplitude-wasserstein-1 norm-1 - OK
# 218. channel-31 life all sum - SKIP (max_corr = 0.9999999999999998)
# 219. channel-31 life all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 220. channel-25 life dim-1 norm-2 - SKIP (max_corr = 0.9996072593130331)
# 221. channel-25 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.9996072593130331)
# 222. channel-26 life all max - SKIP (max_corr = 0.9967633598300073)
# 223. channel-16 bd2 all norm-2 - OK
# 224. channel-26 bd2 dim-2 mean - OK
# 225. channel-26 amplitude-betti-2 norm-2 - OK
# 226. channel-7 bd2 dim-1 mean - OK
# 227. channel-1 amplitude-landscape-2-2 norm-1 - OK
# 228. channel-26 amplitude-betti-2 norm-1 - SKIP (max_corr = 0.9964073067876694)
# 229. channel-31 life dim-1 norm-1 - SKIP (max_corr = 0.9975952416924073)
# 230. channel-31 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9975952416924073)
# 231. channel-31 life dim-1 sum - SKIP (max_corr = 0.9975952416924073)
# 232. channel-6 bd2 dim-2 mean - OK
# 233. channel-2 amplitude-landscape-1-2 dim-1 - OK
# 234. channel-7 life dim-1 norm-2 - OK
# 235. channel-7 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 1.0)
# 236. channel-12 amplitude-silhouette-2-1 dim-1 - OK
# 237. channel-2 amplitude-landscape-1-2 norm-1 - SKIP (max_corr = 0.9997297944800917)
# 238. overall amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9902806608150461)
# 239. channel-26 life all std - OK
# 240. channel-34 life all norm-1 - OK
# 241. channel-34 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 242. channel-34 life all sum - SKIP (max_corr = 0.9999999999999998)
# 243. channel-7 bd2 all mean - SKIP (max_corr = 0.9976258646058507)
# 244. channel-25 amplitude-silhouette-2-2 dim-2 - OK
# 245. channel-25 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.999608833997187)
# 246. channel-12 amplitude-wasserstein-1 dim-1 - OK
# 247. channel-12 life dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 248. channel-12 life dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 249. channel-11 amplitude-silhouette-1-1 norm-2 - SKIP (max_corr = 0.9998354069371309)
# 250. channel-6 bd2 dim-2 norm-2 - SKIP (min_stage_length = 39.0)
# 251. channel-0 entropy dim-1 - OK
# 252. channel-2 amplitude-landscape-1-2 norm-2 - SKIP (max_corr = 0.9999971957324784)
# 253. channel-12 amplitude-wasserstein-1 norm-2 - SKIP (min_stage_length = 37.0)
# 254. channel-12 life all sum - SKIP (max_corr = 0.9962371398298936)
# 255. channel-12 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9962371398298936)
# 256. channel-12 life all norm-1 - SKIP (max_corr = 0.9962371398298936)
# 257. channel-32 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9999913510903928)
# 258. channel-11 amplitude-landscape-1-1 dim-2 - OK
# 259. channel-23 amplitude-silhouette-1-2 dim-1 - SKIP (max_corr = 0.99942475907556)
# 260. channel-12 amplitude-silhouette-2-1 norm-2 - SKIP (max_corr = 0.9997616959538258)
# 261. channel-2 amplitude-bottleneck norm-2 - OK
# 262. channel-6 life all norm-2 - OK
# 263. channel-6 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 1.0)
# 264. channel-2 life all max - SKIP (max_corr = 0.9993667869893771)
# 265. channel-2 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9993091735462927)
# 266. channel-2 life dim-1 max - SKIP (max_corr = 0.9993091735462927)
# 267. channel-26 life dim-2 norm-2 - OK
# 268. channel-26 amplitude-wasserstein-2 dim-2 - SKIP (max_corr = 1.0)
# 269. channel-23 amplitude-silhouette-1-2 norm-2 - SKIP (max_corr = 0.9997809177107834)
# 270. channel-16 bd2 all norm-1 - OK
# 271. channel-16 bd2 all sum - SKIP (max_corr = 1.0)
# 272. channel-31 life dim-1 norm-2 - OK
# 273. channel-31 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 1.0)
# 274. channel-16 bd2 dim-1 norm-2 - OK
# 275. channel-26 life all mean - OK
# 276. channel-31 bd2 dim-1 max - OK
# 277. channel-21 amplitude-silhouette-1-2 norm-2 - OK
# 278. channel-7 amplitude-silhouette-2-2 dim-1 - OK
# 279. overall bd2 all sum - OK
# 280. overall bd2 all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 281. channel-32 bd2 dim-1 max - OK
# 282. channel-12 amplitude-betti-1 norm-1 - OK
# 283. channel-31 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9976387137077901)
# 284. channel-6 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.9984805154662145)
# 285. channel-6 life dim-1 norm-2 - SKIP (max_corr = 0.9984805154662145)
# 286. channel-7 life all norm-1 - OK
# 287. channel-7 life all sum - SKIP (max_corr = 1.0)
# 288. channel-7 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 1.0)
# 289. channel-11 amplitude-landscape-2-2 norm-1 - OK
# 290. channel-1 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9958759388398152)
# 291. channel-25 amplitude-bottleneck norm-1 - OK
# 292. channel-26 amplitude-landscape-1-1 norm-1 - SKIP (max_corr = 0.9937002377786147)
# 293. overall entropy dim-1 - OK
# 294. channel-31 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.999427627393729)
# 295. channel-31 life all norm-2 - SKIP (max_corr = 0.999427627393729)
# 296. channel-7 amplitude-silhouette-2-2 norm-2 - SKIP (max_corr = 0.9986328645843131)
# 297. channel-13 bd2 dim-1 norm-2 - OK
# 298. channel-21 amplitude-silhouette-1-2 dim-1 - SKIP (max_corr = 0.9999280264987718)
# 299. channel-18 amplitude-silhouette-2-1 norm-1 - OK
# 300. channel-21 amplitude-silhouette-1-1 norm-1 - SKIP (max_corr = 0.9912188733536523)
# 301. channel-25 amplitude-landscape-2-1 norm-2 - SKIP (max_corr = 0.9942994903797837)
# 302. channel-26 amplitude-silhouette-2-2 norm-2 - SKIP (max_corr = 0.9929657104323459)
# 303. channel-2 amplitude-landscape-1-1 norm-2 - OK
# 304. channel-25 amplitude-landscape-2-1 dim-1 - SKIP (max_corr = 0.9938427129444788)
# 305. channel-7 amplitude-silhouette-2-1 norm-1 - OK
# 306. channel-13 amplitude-silhouette-2-1 dim-2 - OK
# 307. channel-7 amplitude-betti-1 norm-1 - OK
# 308. channel-21 amplitude-silhouette-1-1 dim-1 - SKIP (max_corr = 0.9918502564781193)
# 309. channel-12 amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9967155398426633)
# 310. channel-12 amplitude-landscape-1-1 dim-2 - OK
# 311. channel-21 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.9998532936479099)
# 312. channel-25 amplitude-bottleneck norm-2 - OK
# 313. channel-21 amplitude-silhouette-1-1 norm-2 - SKIP (max_corr = 0.9917738473697091)
# 314. channel-26 amplitude-betti-2 dim-1 - SKIP (max_corr = 0.9999563859656342)
# 315. channel-12 amplitude-landscape-1-2 dim-2 - SKIP (max_corr = 0.9902865891364114)
# 316. channel-7 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.9986352213291548)
# 317. channel-0 amplitude-landscape-2-1 norm-2 - SKIP (min_stage_length = 12.0)
# 318. channel-25 life all std - OK
# 319. channel-7 amplitude-silhouette-1-1 dim-2 - OK
# 320. channel-1 amplitude-silhouette-1-1 dim-1 - SKIP (min_stage_length = 12.0)
# 321. channel-7 life dim-1 sum - SKIP (max_corr = 0.9923427855790578)
# 322. channel-7 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9923427855790578)
# 323. channel-7 life dim-1 norm-1 - SKIP (max_corr = 0.9923427855790578)
# 324. channel-15 amplitude-bottleneck dim-1 - OK
# 325. channel-15 life dim-1 max - SKIP (max_corr = 0.9999999999999998)
# 326. channel-15 bd2 all sum - OK
# 327. channel-15 bd2 all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 328. channel-7 amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9936714831898114)
# 329. channel-37 bd2 dim-1 norm-1 - OK
# 330. channel-37 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 331. channel-6 bd2 dim-2 norm-1 - OK
# 332. channel-6 bd2 dim-2 sum - SKIP (max_corr = 0.9999999999999998)
# 333. channel-12 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9953804513873956)
# 334. channel-6 life all norm-1 - SKIP (max_corr = 0.9938446514630852)
# 335. channel-6 life all sum - SKIP (max_corr = 0.9938446514630852)
# 336. channel-6 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9938446514630852)
# 337. channel-7 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.998411688962211)
# 338. channel-7 life all norm-2 - SKIP (max_corr = 0.9984116889622108)
# 339. overall numberofpoints dim-1 - OK
# 340. channel-1 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9970996652555082)
# 341. channel-25 life all max - SKIP (max_corr = 0.9977740717312035)
# 342. channel-0 life dim-1 std - OK
# 343. channel-26 life dim-1 mean - SKIP (max_corr = 0.9905708136581493)
# 344. channel-0 amplitude-silhouette-1-1 dim-1 - SKIP (min_stage_length = 15.0)
# 345. channel-1 amplitude-silhouette-2-2 dim-1 - SKIP (min_stage_length = 12.0)
# 346. channel-1 amplitude-silhouette-1-1 norm-2 - SKIP (min_stage_length = 12.0)
# 347. channel-7 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9913814791806108)
# 348. channel-25 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9967379952334608)
# 349. channel-25 life dim-1 max - SKIP (max_corr = 0.9967379952334608)
# 350. overall amplitude-wasserstein-2 norm-2 - OK
# 351. overall life all norm-2 - SKIP (max_corr = 1.0)
# 352. channel-25 life dim-1 std - SKIP (max_corr = 0.998986461719895)
# 353. channel-14 amplitude-silhouette-1-1 dim-2 - OK
# 354. channel-1 amplitude-silhouette-2-1 dim-1 - SKIP (min_stage_length = 11.0)
# 355. channel-0 amplitude-silhouette-1-1 norm-2 - SKIP (min_stage_length = 15.0)
# 356. channel-7 amplitude-silhouette-1-1 norm-2 - OK
# 357. channel-19 amplitude-silhouette-1-2 norm-2 - OK
# 358. channel-7 amplitude-silhouette-1-1 dim-1 - SKIP (max_corr = 0.9986621388283505)
# 359. channel-19 amplitude-silhouette-1-2 dim-1 - SKIP (max_corr = 0.9999028016282083)
# 360. channel-19 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.9997232029471957)
# 361. channel-19 amplitude-silhouette-1-1 norm-2 - OK
# 362. channel-11 bd2 dim-2 sum - SKIP (min_stage_length = 34.0)
# 363. channel-11 bd2 dim-2 norm-1 - SKIP (min_stage_length = 34.0)
# 364. channel-11 bd2 dim-2 norm-2 - OK
# 365. channel-35 bd2 all norm-2 - OK
# 366. channel-0 life all std - SKIP (max_corr = 0.999134514864929)
# 367. channel-33 amplitude-wasserstein-1 dim-1 - OK
# 368. channel-33 life dim-1 norm-1 - SKIP (max_corr = 1.0)
# 369. channel-33 life dim-1 sum - SKIP (max_corr = 1.0)
# 370. overall life dim-1 norm-2 - SKIP (max_corr = 0.9932285607010267)
# 371. overall amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.9932285607010267)
# 372. channel-33 bd2 dim-1 norm-1 - OK
# 373. channel-33 bd2 dim-1 sum - SKIP (max_corr = 1.0)
# 374. channel-33 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9999852597075294)
# 375. channel-8 bd2 dim-1 norm-2 - OK
# 376. channel-35 bd2 dim-1 mean - OK
# 377. channel-0 amplitude-silhouette-1-1 norm-1 - SKIP (min_stage_length = 15.0)
# 378. channel-2 amplitude-landscape-2-2 norm-1 - SKIP (max_corr = 0.9910942972794543)
# 379. channel-31 bd2 all max - OK
# 380. channel-27 amplitude-wasserstein-1 norm-2 - OK
# 381. channel-31 life dim-1 mean - OK
# 382. channel-16 bd2 dim-1 mean - OK
# 383. channel-12 bd2 dim-1 max - OK
# 384. channel-19 amplitude-silhouette-2-2 norm-2 - OK
# 385. channel-12 amplitude-landscape-1-2 dim-1 - OK
# 386. channel-11 amplitude-wasserstein-2 norm-1 - OK
# 387. channel-25 amplitude-silhouette-2-2 norm-2 - SKIP (max_corr = 0.9980066401641945)
# 388. channel-1 amplitude-silhouette-1-1 norm-1 - SKIP (min_stage_length = 12.0)
# 389. channel-0 bd2 dim-1 norm-2 - OK
# 390. channel-2 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9987797716846669)
# 391. channel-33 amplitude-betti-1 dim-1 - OK
# 392. channel-27 life dim-1 norm-1 - SKIP (max_corr = 0.9999878003520695)
# 393. channel-27 life dim-1 sum - SKIP (max_corr = 0.9999878003520695)
# 394. channel-27 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9999878003520695)
# 395. channel-11 amplitude-wasserstein-1 dim-2 - OK
# 396. channel-11 life dim-2 norm-1 - SKIP (max_corr = 1.0)
# 397. channel-11 life dim-2 sum - SKIP (max_corr = 1.0)
# 398. channel-36 bd2 dim-1 mean - OK
# 399. channel-12 life dim-2 norm-2 - SKIP (min_stage_length = 30.0)
# 400. channel-12 amplitude-wasserstein-2 dim-2 - SKIP (min_stage_length = 30.0)
# 401. channel-23 amplitude-silhouette-1-1 dim-1 - OK
# 402. channel-33 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9961674258793272)
# 403. channel-33 amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9999845637369839)
# 404. channel-11 amplitude-wasserstein-2 norm-2 - OK
# 405. channel-11 life all norm-2 - SKIP (max_corr = 0.9999999999999998)
# 406. channel-11 amplitude-wasserstein-1 norm-1 - OK
# 407. channel-11 life all norm-1 - SKIP (max_corr = 1.0)
# 408. channel-11 life all sum - SKIP (max_corr = 1.0)
# 409. channel-21 amplitude-landscape-1-1 dim-1 - OK
# 410. channel-25 bd2 dim-2 mean - OK
# 411. channel-10 bd2 all norm-1 - OK
# 412. channel-10 bd2 all sum - SKIP (max_corr = 0.9999999999999998)
# 413. channel-31 amplitude-wasserstein-2 norm-1 - OK
# 414. channel-27 life all norm-1 - SKIP (max_corr = 0.9975701576689083)
# 415. channel-27 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9975701576689083)
# 416. channel-27 life all sum - SKIP (max_corr = 0.9975701576689083)
# 417. channel-25 amplitude-landscape-2-1 dim-2 - SKIP (max_corr = 0.9978054772726322)
# 418. channel-6 amplitude-betti-1 norm-1 - OK
# 419. channel-22 life dim-2 std - OK
# 420. channel-11 amplitude-silhouette-2-1 dim-1 - OK
# 421. channel-7 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9943752974649515)
# 422. channel-31 life all mean - SKIP (max_corr = 0.9943684622934306)
# 423. channel-19 amplitude-silhouette-1-1 dim-1 - SKIP (max_corr = 0.9995957279533499)
# 424. channel-2 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9934433350531005)
# 425. channel-2 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9934433100728862)
# 426. channel-1 life all std - OK
# 427. channel-0 amplitude-silhouette-2-1 dim-1 - SKIP (min_stage_length = 15.0)
# 428. channel-1 amplitude-silhouette-2-1 norm-2 - SKIP (min_stage_length = 11.0)
# 429. channel-0 amplitude-silhouette-1-2 norm-1 - SKIP (min_stage_length = 15.0)
# 430. channel-23 amplitude-silhouette-1-1 norm-1 - SKIP (max_corr = 0.9990569253555671)
# 431. channel-0 numberofpoints dim-1 - OK
# 432. channel-11 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.9988287902357053)
# 433. channel-11 life dim-1 norm-2 - SKIP (max_corr = 0.9988287902357053)
# 434. channel-12 bd2 all max - OK
# 435. channel-11 bd2 all max - OK
# 436. channel-8 amplitude-wasserstein-2 norm-1 - OK
# 437. channel-17 bd2 dim-2 mean - OK
# 438. channel-26 amplitude-silhouette-1-1 norm-1 - OK
# 439. channel-11 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9949895081791561)
# 440. channel-13 amplitude-wasserstein-1 dim-1 - OK
# 441. channel-13 life dim-1 norm-1 - SKIP (max_corr = 1.0)
# 442. channel-13 life dim-1 sum - SKIP (max_corr = 1.0)
# 443. channel-7 bd2 dim-2 mean - OK
# 444. channel-8 life dim-1 norm-2 - OK
# 445. channel-8 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 1.0)
# 446. channel-27 amplitude-betti-1 dim-1 - OK
# 447. channel-35 life dim-1 norm-1 - OK
# 448. channel-35 life dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 449. channel-35 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9999999999999998)
# 450. channel-36 life dim-1 norm-2 - OK
# 451. channel-36 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 1.0)
# 452. channel-7 bd2 dim-2 norm-1 - SKIP (min_stage_length = 14.0)
# 453. channel-7 bd2 dim-2 sum - SKIP (min_stage_length = 14.0)
# 454. channel-0 amplitude-silhouette-2-1 norm-2 - SKIP (min_stage_length = 15.0)
# 455. channel-0 amplitude-betti-2 norm-1 - OK
# 456. channel-0 amplitude-silhouette-2-1 norm-1 - SKIP (min_stage_length = 32.0)
# 457. channel-36 bd2 all mean - SKIP (max_corr = 0.9947705040299718)
# 458. channel-26 amplitude-silhouette-1-2 dim-1 - SKIP (max_corr = 0.9957170034744524)
# 459. channel-11 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.993302093302961)
# 460. channel-26 bd2 all std - OK
# 461. channel-36 life all mean - OK
# 462. channel-18 amplitude-silhouette-1-1 dim-1 - OK
# 463. channel-33 life all sum - SKIP (max_corr = 0.9965022290644042)
# 464. channel-33 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9965022290644042)
# 465. channel-33 life all norm-1 - SKIP (max_corr = 0.9965022290644042)
# 466. channel-18 amplitude-silhouette-1-1 norm-2 - SKIP (max_corr = 0.9999792584205345)
# 467. channel-27 bd2 all norm-1 - OK
# 468. channel-27 bd2 all sum - SKIP (max_corr = 1.0)
# 469. channel-26 amplitude-silhouette-2-1 norm-2 - OK
# 470. channel-25 life dim-2 mean - OK
# 471. channel-0 bd2 dim-1 norm-1 - OK
# 472. channel-0 bd2 dim-1 sum - SKIP (max_corr = 1.0)
# 473. channel-8 bd2 all norm-2 - OK
# 474. channel-27 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9968654934291733)
# 475. channel-15 amplitude-silhouette-1-2 norm-1 - OK
# 476. channel-32 bd2 dim-1 mean - OK
# 477. channel-10 bd2 all norm-2 - OK
# 478. channel-30 life all norm-2 - OK
# 479. channel-30 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 1.0)
# 480. channel-11 life all mean - OK
# 481. channel-17 amplitude-silhouette-1-2 norm-1 - OK
# 482. channel-8 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9995333429670099)
# 483. channel-8 life all norm-2 - SKIP (max_corr = 0.9995333429670101)
# 484. channel-30 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.9989717648671498)
# 485. channel-30 life dim-1 norm-2 - SKIP (max_corr = 0.9989717648671498)
# 486. channel-27 bd2 all norm-2 - OK
# 487. channel-12 amplitude-wasserstein-2 norm-1 - OK
# 488. channel-26 bd2 dim-1 max - OK
# 489. channel-19 amplitude-silhouette-2-1 norm-1 - OK
# 490. channel-35 bd2 dim-1 norm-2 - OK
# 491. channel-11 amplitude-betti-1 dim-2 - OK
# 492. channel-27 bd2 dim-1 sum - OK
# 493. channel-27 bd2 dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 494. overall amplitude-wasserstein-2 norm-1 - OK
# 495. channel-1 entropy dim-1 - SKIP (min_stage_length = 32.0)
# 496. channel-11 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9956133138320896)
# 497. channel-12 entropy dim-1 - OK
# 498. channel-11 life dim-1 std - OK
# 499. channel-6 amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9949257915098155)
# 500. channel-13 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9999221357652333)
# 501. channel-25 bd2 dim-1 mean - OK
# 502. channel-0 amplitude-betti-2 norm-2 - SKIP (max_corr = 0.9915340600382622)
# 503. channel-35 bd2 all mean - SKIP (max_corr = 0.9946669876095748)
# 504. channel-13 amplitude-landscape-1-2 norm-1 - OK
# 505. channel-12 amplitude-silhouette-1-1 norm-1 - OK
# 506. channel-12 amplitude-landscape-2-2 dim-2 - SKIP (min_stage_length = 34.0)
# 507. channel-17 amplitude-silhouette-1-1 dim-2 - OK
# 508. channel-13 amplitude-silhouette-1-2 dim-1 - OK
# 509. channel-8 amplitude-betti-1 norm-2 - OK
# 510. channel-35 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9920373710439542)
# 511. channel-35 life all norm-1 - SKIP (max_corr = 0.9920373710439542)
# 512. channel-35 life all sum - SKIP (max_corr = 0.9920373710439542)
# 513. channel-18 amplitude-silhouette-1-1 norm-1 - SKIP (max_corr = 0.9998529810597669)
# 514. channel-0 amplitude-landscape-2-1 dim-1 - SKIP (max_corr = 0.9905241626540113)
# 515. channel-19 amplitude-silhouette-1-1 norm-1 - SKIP (max_corr = 0.9994930489428173)
# 516. channel-13 amplitude-betti-1 norm-2 - OK
# 517. channel-0 amplitude-bottleneck norm-2 - OK
# 518. channel-1 amplitude-landscape-1-1 dim-1 - SKIP (min_stage_length = 11.0)
# 519. channel-0 life dim-1 max - SKIP (max_corr = 0.9991750406619296)
# 520. channel-0 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9991750406619296)
# 521. channel-0 life all max - SKIP (max_corr = 0.9991750406619296)
# 522. channel-36 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9995560119980396)
# 523. channel-36 life all norm-2 - SKIP (max_corr = 0.9995560119980396)
# 524. channel-1 amplitude-landscape-1-1 norm-2 - SKIP (min_stage_length = 11.0)
# 525. channel-0 amplitude-landscape-1-1 dim-1 - OK
# 526. channel-13 amplitude-silhouette-1-2 norm-2 - SKIP (max_corr = 0.999649576040146)
# 527. channel-11 amplitude-silhouette-2-2 norm-2 - OK
# 528. channel-6 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9932192494712514)
# 529. channel-0 amplitude-landscape-1-1 norm-2 - SKIP (max_corr = 0.9999903031267505)
# 530. channel-11 amplitude-silhouette-2-2 dim-1 - SKIP (max_corr = 0.9997127320177644)
# 531. channel-6 bd2 dim-1 max - OK
# 532. channel-3 bd2 dim-1 sum - OK
# 533. channel-3 bd2 dim-1 norm-1 - SKIP (max_corr = 1.0)
# 534. channel-2 amplitude-bottleneck norm-1 - SKIP (max_corr = 0.9941471592238468)
# 535. channel-17 amplitude-landscape-1-2 norm-1 - OK
# 536. channel-0 bd2 all std - OK
# 537. channel-21 amplitude-landscape-1-1 norm-1 - SKIP (max_corr = 0.9996639657252407)
# 538. channel-1 amplitude-bottleneck dim-1 - OK
# 539. channel-1 life dim-1 max - SKIP (max_corr = 1.0)
# 540. channel-15 amplitude-landscape-2-1 dim-1 - OK
# 541. channel-21 amplitude-landscape-1-1 norm-2 - SKIP (max_corr = 0.9999859569487365)
# 542. channel-31 amplitude-betti-2 dim-1 - OK
# 543. channel-11 life dim-1 mean - OK
# 544. channel-1 life all max - SKIP (max_corr = 0.9999610725302214)
# 545. channel-36 amplitude-silhouette-2-2 norm-2 - OK
# 546. channel-28 amplitude-landscape-1-2 dim-2 - SKIP (min_stage_length = 32.0)
# 547. channel-0 amplitude-bottleneck norm-1 - SKIP (max_corr = 0.9925921063422474)
# 548. channel-13 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9925426991603118)
# 549. channel-0 amplitude-landscape-1-1 norm-1 - SKIP (max_corr = 0.9996627199639554)
# 550. channel-0 amplitude-silhouette-2-2 dim-1 - SKIP (min_stage_length = 13.0)
# 551. channel-0 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9981358803505442)
# 552. channel-7 amplitude-landscape-1-2 dim-2 - OK
# 553. channel-21 amplitude-silhouette-2-2 dim-1 - OK
# 554. channel-32 bd2 all mean - SKIP (max_corr = 0.9960709047788944)
# 555. channel-5 bd2 dim-1 norm-1 - OK
# 556. channel-5 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 557. channel-30 amplitude-wasserstein-1 norm-1 - OK
# 558. channel-30 life all sum - SKIP (max_corr = 0.9999999999999998)
# 559. channel-30 life all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 560. channel-8 life dim-1 sum - OK
# 561. channel-8 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9999999999999998)
# 562. channel-8 life dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 563. channel-2 life dim-1 std - OK
# 564. channel-31 amplitude-bottleneck norm-1 - OK
# 565. channel-36 amplitude-silhouette-2-2 dim-1 - SKIP (max_corr = 0.9991683730485282)
# 566. channel-0 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9986132734364965)
# 567. channel-6 bd2 all max - OK
# 568. channel-12 life dim-2 sum - OK
# 569. channel-12 amplitude-wasserstein-1 dim-2 - SKIP (max_corr = 0.9999999999999998)
# 570. channel-12 life dim-2 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 571. channel-32 amplitude-betti-2 dim-1 - OK
# 572. channel-7 amplitude-silhouette-2-1 dim-2 - OK
# 573. channel-21 amplitude-silhouette-2-2 norm-2 - SKIP (max_corr = 0.9995034411424655)
# 574. channel-36 life dim-1 mean - SKIP (max_corr = 0.9921513587085953)
# 575. channel-13 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9998992966389455)
# 576. channel-2 amplitude-silhouette-2-1 dim-1 - SKIP (max_corr = 0.9951050487941558)
# 577. channel-11 amplitude-landscape-1-2 norm-1 - SKIP (min_stage_length = 22.0)
# 578. channel-25 life dim-2 max - OK
# 579. channel-25 amplitude-bottleneck dim-2 - SKIP (max_corr = 1.0)
# 580. channel-1 amplitude-landscape-1-1 norm-1 - SKIP (min_stage_length = 11.0)
# 581. channel-30 bd2 all sum - OK
# 582. channel-30 bd2 all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 583. channel-15 amplitude-bottleneck norm-2 - SKIP (max_corr = 0.993267892565966)
# 584. channel-15 amplitude-silhouette-2-2 norm-2 - OK
# 585. channel-11 life all std - SKIP (max_corr = 0.9979453969565882)
# 586. channel-2 amplitude-silhouette-2-1 norm-2 - SKIP (max_corr = 0.997571033555321)
# 587. channel-21 amplitude-silhouette-2-1 norm-2 - OK
# 588. channel-22 amplitude-silhouette-1-1 dim-2 - OK
# 589. channel-12 amplitude-betti-1 dim-2 - OK
# 590. channel-0 amplitude-wasserstein-1 norm-2 - OK
# 591. channel-13 bd2 dim-2 max - OK
# 592. channel-0 life dim-1 sum - SKIP (max_corr = 0.9999497069996127)
# 593. channel-0 life dim-1 norm-1 - SKIP (max_corr = 0.9999497069996127)
# 594. channel-0 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9999497069996127)
# 595. channel-11 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9963598829792605)
# 596. channel-25 bd2 all mean - SKIP (max_corr = 0.9948717652499904)
# 597. channel-13 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.9974729492382214)
# 598. channel-31 amplitude-bottleneck norm-2 - OK
# 599. channel-11 bd2 dim-1 max - OK
# 600. channel-37 bd2 dim-1 norm-2 - OK
# 601. channel-1 amplitude-bottleneck norm-1 - OK
# 602. channel-17 amplitude-landscape-1-1 norm-2 - OK
# 603. channel-17 amplitude-landscape-1-1 dim-1 - SKIP (max_corr = 0.9998983700437907)
# 604. channel-22 amplitude-silhouette-1-2 dim-2 - SKIP (min_stage_length = 22.0)
# 605. channel-15 amplitude-landscape-1-2 norm-2 - OK
# 606. channel-15 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.999843159105605)
# 607. channel-23 bd2 dim-1 std - OK
# 608. channel-11 bd2 dim-2 max - OK
# 609. channel-1 numberofpoints dim-1 - OK
# 610. channel-23 amplitude-silhouette-1-1 norm-2 - SKIP (max_corr = 0.9996384095693737)
# 611. channel-12 amplitude-landscape-2-1 dim-1 - OK
# 612. channel-3 bd2 dim-1 norm-2 - OK
# 613. channel-7 bd2 dim-2 norm-2 - OK
# 614. channel-19 amplitude-silhouette-2-2 dim-1 - SKIP (max_corr = 0.9992879422297237)
# 615. channel-0 bd2 dim-2 max - OK
# 616. channel-36 amplitude-landscape-1-1 norm-2 - OK
# 617. channel-36 bd2 dim-1 norm-2 - OK
# 618. channel-1 amplitude-betti-2 norm-2 - OK
# 619. channel-34 life dim-1 norm-2 - OK
# 620. channel-34 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 1.0)
# 621. channel-15 amplitude-landscape-2-2 norm-2 - OK
# 622. channel-1 amplitude-betti-2 dim-1 - SKIP (max_corr = 0.9998623044010314)
# 623. channel-27 life dim-1 norm-2 - OK
# 624. channel-27 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 1.0)
# 625. channel-17 amplitude-silhouette-1-2 dim-2 - SKIP (max_corr = 0.9908786254934374)
# 626. channel-37 bd2 all mean - OK
# 627. channel-1 amplitude-bottleneck norm-2 - SKIP (max_corr = 0.9982927574723564)
# 628. channel-19 amplitude-silhouette-2-1 norm-2 - SKIP (max_corr = 0.9967550699711057)
# 629. channel-21 amplitude-silhouette-2-1 dim-1 - SKIP (max_corr = 0.9981267743859114)
# 630. channel-31 amplitude-betti-2 norm-1 - SKIP (max_corr = 0.9926901037226114)
# 631. channel-22 life dim-2 mean - OK
# 632. channel-6 amplitude-landscape-1-2 dim-2 - OK
# 633. channel-21 amplitude-silhouette-2-2 norm-1 - SKIP (max_corr = 0.9974929940167492)
# 634. channel-10 entropy dim-1 - SKIP (min_stage_length = 34.0)
# 635. channel-4 bd2 dim-1 sum - OK
# 636. channel-4 bd2 dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 637. channel-4 amplitude-betti-1 norm-2 - OK
# 638. channel-13 amplitude-bottleneck dim-2 - OK
# 639. channel-13 life dim-2 max - SKIP (max_corr = 0.9999999999999998)
# 640. channel-10 bd2 dim-1 norm-1 - OK
# 641. channel-10 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 642. channel-0 amplitude-landscape-1-2 norm-2 - SKIP (max_corr = 0.9997838566709959)
# 643. channel-25 bd2 dim-2 max - OK
# 644. channel-30 bd2 dim-1 mean - OK
# 645. channel-31 amplitude-landscape-2-2 norm-1 - OK
# 646. channel-13 amplitude-silhouette-1-1 norm-2 - OK
# 647. channel-23 amplitude-silhouette-1-1 dim-2 - OK
# 648. channel-7 entropy dim-1 - OK
# 649. channel-6 amplitude-silhouette-1-2 norm-2 - OK
# 650. channel-13 amplitude-silhouette-2-2 norm-2 - OK
# 651. channel-1 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9969970137955152)
# 652. channel-1 bd2 dim-1 sum - OK
# 653. channel-1 bd2 dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 654. channel-32 bd2 dim-1 std - OK
# 655. channel-37 bd2 all norm-2 - OK
# 656. channel-0 bd2 dim-1 max - OK
# 657. channel-2 amplitude-silhouette-1-1 norm-2 - SKIP (min_stage_length = 15.0)
# 658. channel-16 bd2 all mean - SKIP (max_corr = 0.9966963635174746)
# 659. channel-1 life dim-1 std - SKIP (max_corr = 0.9990213031952276)
# 660. channel-6 amplitude-silhouette-1-1 dim-2 - OK
# 661. channel-2 life all std - SKIP (max_corr = 0.9987354467408283)
# 662. channel-35 amplitude-betti-1 norm-1 - OK
# 663. channel-36 amplitude-landscape-1-1 norm-1 - SKIP (max_corr = 0.998923500997459)
# 664. channel-37 amplitude-wasserstein-2 norm-1 - OK
# 665. channel-6 amplitude-landscape-2-2 dim-1 - OK
# 666. channel-17 bd2 all norm-1 - OK
# 667. channel-17 bd2 all sum - SKIP (max_corr = 0.9999999999999998)
# 668. channel-31 amplitude-betti-2 norm-2 - SKIP (max_corr = 0.9999365686985557)
# 669. channel-26 amplitude-silhouette-2-1 dim-2 - OK
# 670. channel-7 life dim-2 mean - OK
# 671. channel-11 amplitude-bottleneck norm-2 - OK
# 672. channel-11 bd2 dim-2 mean - OK
# 673. channel-30 amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9999754828833881)
# 674. channel-6 amplitude-betti-1 dim-2 - OK
# 675. channel-30 bd2 all mean - SKIP (max_corr = 0.9965133262212647)
# 676. channel-1 amplitude-betti-2 norm-1 - SKIP (max_corr = 0.9921548248469347)
# 677. channel-13 bd2 dim-1 max - OK
# 678. overall life dim-1 mean - OK
# 679. channel-2 amplitude-silhouette-1-1 norm-1 - SKIP (min_stage_length = 16.0)
# 680. channel-0 bd2 dim-2 std - OK
# 681. channel-37 bd2 dim-1 mean - SKIP (max_corr = 0.994560087980514)
# 682. channel-11 amplitude-silhouette-2-1 norm-2 - SKIP (max_corr = 0.9974746145926272)
# 683. channel-30 bd2 all norm-2 - OK
# 684. channel-30 amplitude-wasserstein-2 norm-1 - OK
# 685. channel-30 life dim-1 sum - SKIP (max_corr = 0.9962811389975321)
# 686. channel-30 life dim-1 norm-1 - SKIP (max_corr = 0.9962811389975321)
# 687. channel-30 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9962811389975321)
# 688. channel-13 amplitude-wasserstein-2 norm-1 - OK
# 689. channel-27 life all norm-2 - SKIP (max_corr = 0.9991469874454061)
# 690. channel-27 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9991469874454061)
# 691. channel-22 amplitude-landscape-2-2 dim-2 - OK
# 692. channel-6 amplitude-silhouette-1-1 norm-1 - OK
# 693. channel-32 amplitude-wasserstein-2 norm-1 - OK
# 694. channel-7 amplitude-landscape-1-1 dim-2 - OK
# 695. channel-30 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9967592900820883)
# 696. channel-31 life dim-1 max - SKIP (max_corr = 0.9975313093863638)
# 697. channel-31 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9975313093863638)
# 698. channel-6 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9994771925307514)
# 699. channel-2 amplitude-silhouette-1-1 dim-1 - SKIP (min_stage_length = 16.0)
# 700. channel-2 amplitude-betti-1 dim-1 - OK
# 701. channel-11 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9949588393141366)
# 702. channel-15 amplitude-silhouette-2-1 dim-1 - OK
# 703. channel-17 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.998874467596774)
# 704. channel-31 life all max - SKIP (max_corr = 0.9975752437850418)
# 705. channel-31 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9942138790603257)
# 706. channel-10 amplitude-betti-1 dim-1 - OK
# 707. channel-37 life all std - OK
# 708. channel-36 life all std - OK
# 709. channel-0 amplitude-landscape-1-2 dim-1 - SKIP (min_stage_length = 13.0)
# 710. channel-16 amplitude-silhouette-2-2 norm-2 - OK
# 711. channel-11 amplitude-betti-1 norm-2 - SKIP (max_corr = 0.9998642720070309)
# 712. channel-6 amplitude-landscape-1-2 norm-1 - OK
# 713. channel-13 bd2 all norm-2 - OK
# 714. channel-6 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.9924156839690815)
# 715. channel-8 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9999594367435478)
# 716. channel-33 bd2 all sum - OK
# 717. channel-33 bd2 all norm-1 - SKIP (max_corr = 1.0)
# 718. channel-31 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9905134440317297)
# 719. channel-15 amplitude-landscape-2-2 norm-1 - SKIP (max_corr = 0.9905716245584257)
# 720. channel-13 bd2 dim-1 norm-1 - OK
# 721. channel-13 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 722. channel-26 bd2 dim-2 std - OK
# 723. channel-8 amplitude-silhouette-2-1 dim-2 - OK
# 724. channel-35 life all mean - OK
# 725. channel-6 life dim-2 sum - SKIP (min_stage_length = 35.0)
# 726. channel-6 life dim-2 norm-1 - SKIP (min_stage_length = 35.0)
# 727. channel-6 amplitude-wasserstein-1 dim-2 - SKIP (min_stage_length = 35.0)
# 728. channel-27 bd2 dim-1 norm-2 - OK
# 729. channel-36 numberofpoints dim-2 - OK
# 730. channel-18 amplitude-silhouette-1-2 norm-2 - OK
# 731. channel-0 amplitude-betti-2 dim-1 - OK
# 732. channel-18 amplitude-silhouette-1-2 dim-1 - SKIP (max_corr = 0.9999844923552074)
# 733. channel-6 bd2 dim-2 max - OK
# 734. channel-18 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.9999494637479779)
# 735. channel-11 amplitude-landscape-1-2 dim-1 - OK
# 736. channel-21 amplitude-landscape-2-1 dim-1 - OK
# 737. channel-18 amplitude-silhouette-2-1 dim-1 - SKIP (max_corr = 0.998739734332072)
# 738. channel-31 amplitude-landscape-2-1 norm-2 - OK
# 739. channel-11 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 0.9941696649905579)
# 740. channel-11 life dim-1 sum - SKIP (max_corr = 0.9941696649905579)
# 741. channel-11 life dim-1 norm-1 - SKIP (max_corr = 0.9941696649905579)
# 742. channel-16 amplitude-wasserstein-1 norm-2 - OK
# 743. channel-16 life all norm-1 - SKIP (max_corr = 0.9930822379626795)
# 744. channel-16 life all sum - SKIP (max_corr = 0.9930822379626795)
# 745. channel-16 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9930822379626795)
# 746. channel-36 amplitude-wasserstein-1 dim-1 - OK
# 747. channel-36 life dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 748. channel-36 life dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 749. channel-8 bd2 dim-1 mean - OK
# 750. channel-35 amplitude-wasserstein-2 norm-2 - OK
# 751. channel-35 life all norm-2 - SKIP (max_corr = 1.0)
# 752. channel-2 amplitude-silhouette-2-2 norm-1 - OK
# 753. channel-28 amplitude-landscape-1-1 dim-2 - SKIP (min_stage_length = 22.0)
# 754. channel-13 bd2 all mean - OK
# 755. channel-5 life dim-1 sum - OK
# 756. channel-5 life dim-1 norm-1 - SKIP (max_corr = 1.0)
# 757. channel-5 amplitude-wasserstein-1 dim-1 - SKIP (max_corr = 1.0)
# 758. channel-37 life dim-1 std - SKIP (max_corr = 0.998895075404553)
# 759. channel-21 amplitude-silhouette-2-1 norm-1 - SKIP (max_corr = 0.9975662499372208)
# 760. channel-7 amplitude-betti-2 norm-2 - OK
# 761. channel-11 amplitude-landscape-1-2 norm-2 - SKIP (max_corr = 0.9999833743654926)
# 762. channel-0 amplitude-silhouette-1-2 dim-1 - SKIP (min_stage_length = 13.0)
# 763. channel-5 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9999828027298048)
# 764. channel-27 amplitude-wasserstein-2 norm-1 - OK
# 765. channel-15 amplitude-bottleneck norm-1 - OK
# 766. channel-36 amplitude-betti-1 dim-1 - OK
# 767. channel-13 life all norm-2 - OK
# 768. channel-13 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9999999999999998)
# 769. channel-38 amplitude-landscape-2-1 dim-1 - OK
# 770. channel-6 life dim-1 mean - OK
# 771. channel-5 amplitude-bottleneck norm-1 - OK
# 772. channel-35 amplitude-landscape-2-2 norm-2 - OK
# 773. channel-5 amplitude-wasserstein-2 dim-1 - OK
# 774. channel-5 life dim-1 norm-2 - SKIP (max_corr = 1.0)
# 775. channel-36 amplitude-wasserstein-1 norm-2 - SKIP (max_corr = 0.9999464152409069)
# 776. channel-0 amplitude-silhouette-1-2 norm-2 - SKIP (min_stage_length = 13.0)
# 777. channel-18 amplitude-silhouette-2-1 norm-2 - SKIP (max_corr = 0.9993834624183534)
# 778. channel-8 bd2 all mean - SKIP (max_corr = 0.9952583673615181)
# 779. channel-25 life all mean - OK
# 780. channel-6 amplitude-landscape-1-1 dim-2 - OK
# 781. channel-36 amplitude-landscape-1-2 norm-2 - OK
# 782. channel-36 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.9999904707580682)
# 783. overall amplitude-landscape-1-1 dim-3 - OK
# 784. channel-11 amplitude-landscape-2-1 norm-2 - OK
# 785. channel-13 life dim-1 norm-2 - SKIP (max_corr = 0.9993122704944363)
# 786. channel-13 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.9993122704944363)
# 787. channel-11 amplitude-bottleneck norm-1 - OK
# ...
# 1308. channel-12 amplitude-betti-2 norm-1 - SKIP (min_stage_length = 31.0)
# 1309. channel-34 bd2 dim-2 mean - OK
# 1310. channel-16 bd2 all max - OK
# 1311. channel-36 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9916054919222302)
# 1312. channel-6 amplitude-landscape-2-1 dim-1 - SKIP (max_corr = 0.9994363981921094)
# 1313. channel-33 amplitude-silhouette-1-2 dim-1 - SKIP (max_corr = 0.9982316290641998)
# 1314. channel-31 entropy dim-1 - OK
# 1315. channel-17 amplitude-silhouette-2-1 norm-2 - OK
# 1316. channel-33 amplitude-silhouette-2-1 norm-1 - OK
# 1317. channel-39 amplitude-betti-1 norm-2 - OK
# 1318. channel-7 amplitude-betti-2 norm-1 - SKIP (max_corr = 0.9920290256030776)
# 1319. channel-7 amplitude-landscape-2-1 norm-2 - SKIP (max_corr = 0.9939337796898975)
# 1320. channel-31 amplitude-silhouette-2-1 dim-2 - OK
# 1321. channel-6 amplitude-betti-2 norm-1 - OK
# 1322. channel-22 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9973689566814443)
# 1323. channel-22 life dim-1 max - SKIP (max_corr = 0.9973689566814443)
# 1324. channel-22 life all max - SKIP (max_corr = 0.9973689566814443)
# 1325. channel-37 bd2 all norm-1 - OK
# 1326. channel-37 bd2 all sum - SKIP (max_corr = 0.9999999999999998)
# 1327. channel-23 amplitude-landscape-2-1 norm-2 - OK
# 1328. channel-10 amplitude-landscape-2-2 norm-1 - OK
# 1329. channel-30 bd2 dim-2 mean - OK
# 1330. channel-27 amplitude-landscape-2-2 dim-1 - OK
# 1331. channel-14 amplitude-wasserstein-2 norm-1 - OK
# 1332. channel-5 entropy dim-1 - OK
# 1333. channel-31 amplitude-landscape-1-2 norm-1 - SKIP (max_corr = 0.9981892562655891)
# 1334. channel-34 life all norm-2 - SKIP (max_corr = 0.9988906360229619)
# 1335. channel-34 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9988906360229617)
# 1336. channel-31 bd2 all std - OK
# 1337. channel-15 bd2 dim-1 norm-2 - OK
# 1338. channel-24 amplitude-silhouette-2-2 dim-2 - OK
# 1339. channel-14 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.995431347110776)
# 1340. channel-20 bd2 all norm-2 - OK
# 1341. channel-6 amplitude-silhouette-2-2 norm-1 - SKIP (max_corr = 0.9945934414311057)
# 1342. channel-17 amplitude-landscape-2-1 norm-2 - SKIP (max_corr = 0.9956069326093614)
# 1343. channel-17 amplitude-silhouette-2-1 dim-1 - SKIP (max_corr = 0.9917713731919571)
# 1344. channel-6 amplitude-silhouette-2-1 norm-2 - SKIP (max_corr = 0.9932707352033029)
# 1345. channel-39 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9999871164381889)
# 1346. channel-10 amplitude-landscape-2-1 dim-1 - OK
# 1347. channel-16 bd2 dim-2 max - OK
# 1348. channel-33 bd2 dim-1 mean - SKIP (max_corr = 0.9937736769510226)
# 1349. channel-2 amplitude-landscape-1-1 dim-2 - OK
# 1350. channel-22 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9904926597990531)
# 1351. channel-21 bd2 dim-2 max - OK
# 1352. channel-22 amplitude-silhouette-2-1 norm-2 - OK
# 1353. channel-31 amplitude-silhouette-2-2 norm-1 - OK
# 1354. channel-29 bd2 all sum - OK
# 1355. channel-29 bd2 all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 1356. channel-26 amplitude-silhouette-2-1 norm-1 - OK
# 1357. channel-1 amplitude-silhouette-2-2 norm-2 - SKIP (min_stage_length = 34.0)
# 1358. channel-32 amplitude-silhouette-2-2 dim-2 - OK
# 1359. channel-22 life dim-1 std - OK
# 1360. channel-17 life all std - OK
# 1361. channel-27 bd2 dim-2 mean - OK
# 1362. channel-8 amplitude-bottleneck dim-1 - OK
# 1363. channel-8 life dim-1 max - SKIP (max_corr = 0.9999999999999998)
# 1364. channel-18 life all mean - OK
# 1365. channel-37 amplitude-landscape-2-1 norm-2 - OK
# 1366. channel-17 life dim-1 mean - OK
# 1367. channel-8 life all max - SKIP (max_corr = 0.9999920158426184)
# 1368. channel-18 life dim-1 std - SKIP (max_corr = 0.9989372450069433)
# 1369. channel-33 life all max - OK
# 1370. channel-12 amplitude-silhouette-2-2 dim-2 - OK
# 1371. channel-34 life all mean - OK
# 1372. channel-0 amplitude-landscape-1-2 dim-2 - SKIP (max_corr = 0.9915069638890524)
# 1373. channel-6 life dim-2 std - OK
# 1374. channel-26 entropy dim-1 - OK
# 1375. channel-15 life all norm-2 - OK
# 1376. channel-15 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9999999999999998)
# 1377. channel-21 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.9996498020567443)
# 1378. channel-21 amplitude-landscape-1-2 norm-2 - SKIP (max_corr = 0.9997254466045966)
# 1379. channel-9 amplitude-silhouette-1-2 dim-2 - OK
# 1380. channel-33 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9998986036812699)
# 1381. channel-33 life dim-1 max - SKIP (max_corr = 0.9998986036812699)
# 1382. channel-18 bd2 dim-1 std - OK
# 1383. channel-3 bd2 all mean - OK
# 1384. channel-33 amplitude-betti-2 norm-1 - OK
# 1385. channel-33 amplitude-bottleneck norm-2 - SKIP (max_corr = 0.9952423507060392)
# 1386. channel-36 bd2 dim-1 norm-1 - OK
# 1387. channel-36 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 1388. channel-0 amplitude-silhouette-1-1 dim-2 - OK
# 1389. channel-31 amplitude-silhouette-1-1 norm-1 - OK
# 1390. channel-10 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.9910553051757973)
# 1391. channel-11 amplitude-betti-2 norm-2 - OK
# 1392. overall amplitude-betti-2 norm-2 - OK
# 1393. channel-31 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.9999671592234217)
# 1394. channel-13 amplitude-betti-2 dim-1 - OK
# 1395. channel-15 amplitude-wasserstein-2 norm-1 - OK
# 1396. channel-15 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.9985517251936291)
# 1397. channel-15 life dim-1 norm-2 - SKIP (max_corr = 0.9985517251936291)
# 1398. channel-37 life all norm-1 - SKIP (max_corr = 0.9939706666994788)
# 1399. channel-37 amplitude-wasserstein-1 norm-1 - SKIP (max_corr = 0.9939706666994788)
# 1400. channel-37 life all sum - SKIP (max_corr = 0.9939706666994788)
# 1401. channel-20 amplitude-silhouette-2-1 norm-2 - OK
# 1402. channel-3 amplitude-wasserstein-2 dim-1 - OK
# 1403. channel-3 life dim-1 norm-2 - SKIP (max_corr = 0.9999999999999998)
# 1404. channel-15 life all std - OK
# 1405. channel-30 amplitude-betti-2 dim-1 - OK
# 1406. channel-35 entropy dim-2 - OK
# 1407. channel-33 bd2 all max - OK
# 1408. channel-37 amplitude-landscape-1-2 norm-2 - OK
# 1409. channel-30 life dim-1 std - SKIP (max_corr = 0.9982036821817782)
# 1410. channel-32 amplitude-betti-2 norm-2 - SKIP (max_corr = 0.9999592402514141)
# 1411. channel-37 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.9999910923313509)
# 1412. channel-28 amplitude-landscape-2-2 dim-2 - OK
# 1413. channel-17 bd2 dim-2 sum - SKIP (min_stage_length = 33.0)
# 1414. channel-17 bd2 dim-2 norm-1 - SKIP (min_stage_length = 33.0)
# 1415. channel-37 bd2 all max - OK
# 1416. channel-18 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.999220144905472)
# 1417. channel-15 amplitude-betti-1 dim-1 - SKIP (max_corr = 0.9948309611502569)
# 1418. channel-17 life dim-1 std - SKIP (max_corr = 0.9986502673084215)
# 1419. channel-13 bd2 dim-2 norm-2 - OK
# 1420. channel-20 bd2 dim-1 norm-1 - OK
# 1421. channel-20 bd2 dim-1 sum - SKIP (max_corr = 1.0)
# 1422. channel-21 amplitude-silhouette-2-2 dim-2 - OK
# 1423. overall amplitude-bottleneck norm-1 - OK
# 1424. channel-16 bd2 dim-2 mean - OK
# 1425. channel-26 amplitude-betti-1 dim-2 - OK
# 1426. channel-30 amplitude-betti-2 norm-2 - SKIP (max_corr = 0.9998967141427131)
# 1427. channel-30 amplitude-landscape-2-2 dim-1 - OK
# 1428. channel-23 amplitude-landscape-1-2 norm-2 - OK
# 1429. channel-29 amplitude-silhouette-1-2 norm-2 - OK
# 1430. channel-37 amplitude-landscape-2-1 norm-1 - SKIP (max_corr = 0.995325303249535)
# 1431. channel-26 amplitude-silhouette-1-1 dim-2 - SKIP (min_stage_length = 13.0)
# 1432. channel-9 amplitude-silhouette-1-1 norm-1 - OK
# 1433. channel-7 life all mean - OK
# 1434. channel-22 amplitude-landscape-1-1 dim-1 - SKIP (max_corr = 0.9967836190055882)
# 1435. channel-33 amplitude-landscape-1-1 dim-1 - OK
# 1436. channel-22 amplitude-landscape-1-1 norm-2 - SKIP (max_corr = 0.9976639129003716)
# 1437. channel-28 bd2 dim-2 mean - OK
# 1438. channel-10 amplitude-landscape-2-2 norm-2 - OK
# 1439. channel-10 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9988681451964053)
# 1440. channel-29 entropy dim-1 - OK
# 1441. channel-17 entropy dim-1 - OK
# 1442. channel-20 amplitude-silhouette-2-2 norm-1 - OK
# 1443. channel-20 amplitude-silhouette-1-1 norm-2 - OK
# 1444. channel-21 amplitude-wasserstein-1 norm-1 - OK
# 1445. channel-21 life all sum - SKIP (max_corr = 0.9999999999999998)
# 1446. channel-21 life all norm-1 - SKIP (max_corr = 0.9999999999999998)
# 1447. channel-20 amplitude-silhouette-1-1 dim-1 - OK
# 1448. channel-20 amplitude-landscape-1-1 dim-1 - SKIP (max_corr = 0.9931742622494228)
# 1449. channel-37 amplitude-silhouette-2-1 dim-1 - OK
# 1450. channel-16 amplitude-silhouette-2-2 dim-2 - OK
# 1451. channel-36 amplitude-landscape-1-1 dim-2 - OK
# 1452. channel-5 amplitude-wasserstein-2 norm-1 - OK
# 1453. channel-33 bd2 dim-2 mean - OK
# 1454. channel-37 amplitude-landscape-2-1 dim-1 - SKIP (max_corr = 0.9997626303627396)
# 1455. channel-20 amplitude-landscape-1-1 norm-2 - SKIP (max_corr = 0.9954983690545931)
# 1456. channel-37 amplitude-silhouette-2-1 norm-2 - OK
# 1457. channel-0 bd2 all mean - OK
# 1458. channel-7 amplitude-landscape-1-2 dim-1 - SKIP (max_corr = 0.997558347178643)
# 1459. channel-18 bd2 all norm-2 - OK
# 1460. channel-9 bd2 dim-1 mean - SKIP (max_corr = 0.9953750093381691)
# 1461. channel-6 amplitude-bottleneck dim-2 - OK
# 1462. channel-6 life dim-2 max - SKIP (max_corr = 0.9999999999999998)
# 1463. channel-37 life dim-1 norm-2 - SKIP (max_corr = 0.999545221136297)
# 1464. channel-37 amplitude-wasserstein-2 dim-1 - SKIP (max_corr = 0.999545221136297)
# 1465. channel-37 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9942468103755964)
# 1466. channel-13 amplitude-betti-2 norm-2 - SKIP (max_corr = 0.9998086093070401)
# 1467. channel-12 amplitude-landscape-1-2 norm-1 - SKIP (max_corr = 0.9973861833159107)
# 1468. channel-17 bd2 dim-2 norm-2 - OK
# 1469. channel-14 bd2 dim-1 norm-2 - OK
# 1470. channel-39 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9967796518938723)
# 1471. channel-5 amplitude-landscape-2-1 dim-2 - OK
# 1472. channel-34 amplitude-wasserstein-2 norm-1 - OK
# 1473. channel-34 life all max - OK
# 1474. channel-16 amplitude-betti-2 dim-2 - SKIP (min_stage_length = 15.0)
# 1475. channel-37 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9957468992502616)
# 1476. channel-2 amplitude-silhouette-1-2 norm-1 - OK
# 1477. channel-32 amplitude-landscape-2-1 dim-2 - OK
# 1478. channel-7 amplitude-landscape-1-2 norm-2 - SKIP (max_corr = 0.9981231733547931)
# 1479. channel-37 amplitude-landscape-1-2 dim-2 - OK
# 1480. channel-14 amplitude-silhouette-2-1 dim-2 - OK
# 1481. channel-6 amplitude-silhouette-1-2 dim-2 - OK
# 1482. channel-21 amplitude-landscape-2-2 dim-1 - SKIP (max_corr = 0.9966550187699185)
# 1483. channel-30 bd2 all max - OK
# 1484. channel-37 amplitude-landscape-1-2 norm-1 - SKIP (max_corr = 0.9990844069601215)
# 1485. channel-34 life dim-1 max - SKIP (max_corr = 0.9997625341787453)
# 1486. channel-34 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9997625341787453)
# 1487. channel-0 numberofpoints dim-2 - OK
# 1488. channel-4 amplitude-silhouette-1-1 dim-2 - OK
# 1489. channel-35 amplitude-bottleneck dim-1 - SKIP (max_corr = 0.9986471946324765)
# 1490. channel-35 life all max - SKIP (max_corr = 0.9986471946324765)
# 1491. channel-35 life dim-1 max - SKIP (max_corr = 0.9986471946324765)
# 1492. channel-35 amplitude-bottleneck norm-1 - OK
# 1493. channel-6 amplitude-landscape-1-1 dim-1 - SKIP (max_corr = 0.9998514448781207)
# 1494. channel-14 amplitude-landscape-1-1 dim-2 - OK
# 1495. channel-19 amplitude-landscape-1-1 dim-2 - OK
# 1496. channel-37 bd2 all std - OK
# 1497. channel-21 bd2 dim-2 norm-2 - OK
# 1498. channel-27 bd2 all max - OK
# 1499. channel-28 amplitude-landscape-2-1 dim-2 - SKIP (max_corr = 0.997888768219098)
# 1500. channel-37 amplitude-bottleneck norm-2 - OK
# 1501. channel-18 numberofpoints dim-1 - OK
# 1502. channel-30 amplitude-betti-2 norm-1 - SKIP (max_corr = 0.9918156927395388)
# 1503. channel-30 bd2 dim-1 max - OK
# 1504. channel-8 amplitude-bottleneck norm-1 - OK
# 1505. channel-34 amplitude-bottleneck norm-1 - OK
# 1506. channel-17 numberofpoints dim-2 - OK
# 1507. channel-34 bd2 all mean - OK
# 1508. channel-22 amplitude-silhouette-1-2 norm-1 - SKIP (max_corr = 0.9937517775142586)
# 1509. channel-21 life dim-1 std - OK
# 1510. channel-8 amplitude-landscape-2-2 dim-2 - SKIP (max_corr = 0.9968358667970607)
# 1511. channel-17 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.9921863287618744)
# 1512. channel-21 amplitude-landscape-2-2 norm-1 - SKIP (max_corr = 0.9927880878778679)
# 1513. channel-3 amplitude-betti-1 norm-1 - SKIP (max_corr = 0.9927598710731619)
# 1514. channel-39 bd2 dim-1 norm-1 - OK
# 1515. channel-39 bd2 dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 1516. channel-26 life dim-1 std - SKIP (max_corr = 0.9976924754295647)
# 1517. channel-36 amplitude-bottleneck norm-1 - SKIP (max_corr = 0.9900510009558001)
# 1518. channel-37 amplitude-landscape-1-1 norm-2 - OK
# 1519. channel-16 numberofpoints dim-2 - SKIP (min_stage_length = 23.0)
# 1520. channel-15 amplitude-landscape-2-1 norm-1 - OK
# 1521. channel-11 life dim-2 max - OK
# 1522. channel-11 amplitude-bottleneck dim-2 - SKIP (max_corr = 0.9999999999999998)
# 1523. channel-35 bd2 dim-2 mean - OK
# 1524. channel-2 amplitude-landscape-2-2 dim-2 - OK
# 1525. channel-31 amplitude-silhouette-1-2 dim-2 - SKIP (max_corr = 0.994125326531242)
# 1526. channel-17 amplitude-landscape-2-1 dim-1 - SKIP (max_corr = 0.9931152146016974)
# 1527. channel-2 amplitude-wasserstein-1 dim-1 - OK
# 1528. channel-2 life dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 1529. channel-2 life dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 1530. channel-9 amplitude-silhouette-2-1 norm-1 - OK
# 1531. channel-21 amplitude-silhouette-1-2 dim-2 - OK
# 1532. channel-32 amplitude-wasserstein-2 norm-2 - SKIP (max_corr = 0.9994202489811956)
# 1533. channel-32 life all norm-2 - SKIP (max_corr = 0.9994202489811956)
# 1534. channel-7 entropy dim-2 - SKIP (min_stage_length = 6.0)
# 1535. channel-16 life dim-2 norm-1 - OK
# 1536. channel-16 life dim-2 sum - SKIP (max_corr = 1.0)
# 1537. channel-16 amplitude-wasserstein-1 dim-2 - SKIP (max_corr = 1.0)
# 1538. channel-18 bd2 all max - OK
# 1539. channel-21 bd2 all sum - OK
# 1540. channel-21 bd2 all norm-1 - SKIP (max_corr = 1.0)
# 1541. channel-21 life all std - SKIP (max_corr = 0.9990578525819316)
# 1542. channel-23 amplitude-bottleneck norm-2 - OK
# 1543. channel-4 entropy dim-1 - OK
# 1544. channel-11 amplitude-betti-2 norm-1 - SKIP (max_corr = 0.9919354696647804)
# 1545. channel-37 amplitude-bottleneck norm-1 - OK
# 1546. channel-10 amplitude-landscape-2-1 norm-2 - SKIP (max_corr = 0.9982610371172626)
# 1547. channel-5 amplitude-bottleneck norm-2 - OK
# 1548. channel-5 bd2 dim-1 norm-2 - OK
# 1549. channel-21 amplitude-landscape-2-2 norm-2 - SKIP (max_corr = 0.996361371120691)
# 1550. channel-12 life dim-1 std - OK
# 1551. channel-0 entropy dim-2 - OK
# 1552. channel-27 amplitude-landscape-1-2 norm-2 - OK
# 1553. channel-34 amplitude-bottleneck norm-2 - SKIP (max_corr = 0.9958898516188065)
# 1554. channel-1 bd2 dim-1 norm-2 - OK
# 1555. channel-8 bd2 all norm-1 - OK
# 1556. channel-8 bd2 all sum - SKIP (max_corr = 0.9999999999999998)
# 1557. channel-38 amplitude-wasserstein-1 dim-1 - OK
# 1558. channel-38 life dim-1 sum - SKIP (max_corr = 0.9999999999999998)
# 1559. channel-38 life dim-1 norm-1 - SKIP (max_corr = 0.9999999999999998)
# 1560. channel-38 amplitude-betti-1 norm-2 - OK
# (1046, 765)
# (array(['channel-0', 'channel-1', 'channel-10', 'channel-11', 'channel-12',
#        'channel-13', 'channel-14', 'channel-15', 'channel-16',
#        'channel-17', 'channel-18', 'channel-19', 'channel-2',
#        'channel-20', 'channel-21', 'channel-22', 'channel-23',
#        'channel-24', 'channel-25', 'channel-26', 'channel-27',
#        'channel-28', 'channel-29', 'channel-3', 'channel-30',
#        'channel-31', 'channel-32', 'channel-33', 'channel-34',
#        'channel-35', 'channel-36', 'channel-37', 'channel-38',
#        'channel-39', 'channel-4', 'channel-5', 'channel-6', 'channel-7',
#        'channel-8', 'channel-9', 'overall'], dtype='<U32'), array([30, 12, 15, 37, 36, 23, 10, 23, 23, 25, 15,  6, 21, 20, 20, 17, 10,
#         2, 32, 44, 19,  7,  6,  7, 16, 28, 21, 19, 15, 19, 19, 23,  4,  3,
#         8, 15, 43, 33, 16, 10, 13], dtype=int64))

# %% [markdown]
# ### UMAP

# %%
tda_umap = umap.UMAP(n_components = 15, random_state = 42)
umap_features = tda_umap.fit_transform(best_features)
print(umap_features.shape)
# Out:
# (1046, 15)

# %%
umap_result, _ = SDA.SDA(n_jobs = 15, scale = False, verbose = True).apply(umap_features)
display(SDA.analytics.best_results(umap_result, key = 'Avg-Silh'))
# Out:
# Applying to 1046 samples with 15 features each
# Running stage 1
#   0%|          | 0/589 [00:00<?, ?it/s]
# Running stage 2
#   0%|          | 0/672 [00:00<?, ?it/s]
#     St_len_min  K_nb_max  N_cl_max  N_stages  Cl_cen  \
# 0            0        40        10         3    Mode
# 1            0        40        15         4    Mode
# 2            0        45        15         5    Mode
# 3            0        40        10         6    Mode
# 4           20        40        20         7    Mode
# 5            0        40        20         8  Median
# 6            0        40        20         9  Median
# 7            0        40        20        10  Median
# 8            0        40        15        11  Median
# 9            0        50        15        12  Median
# 10           0        40        15        13  Median
# 11           0        40        15        14  Median
# 12          60        35        15        15    Mean
# 13          60        35        15        16    Mean
#
#                                              St_edges    Ward_dist  Cen_dist  \
# 0                                 [0, 284, 682, 1046]  1706.870221  2.603137
# 1                            [0, 284, 682, 787, 1046]  1429.672018  3.149985
# 2                       [0, 284, 554, 682, 787, 1046]  1019.236998  3.231717
# 3                  [0, 284, 554, 682, 842, 976, 1046]   921.508051  3.122669
# 4             [0, 284, 556, 682, 787, 842, 976, 1046]   709.852606  2.864808
# 5          [0, 3, 244, 556, 682, 787, 842, 976, 1046]   638.467706  2.806411
# 6     [0, 3, 244, 284, 556, 682, 787, 842, 976, 1046]   305.223013  2.470137
# 7   [0, 3, 244, 284, 493, 556, 682, 787, 842, 976,...   225.968835  2.212761
# 8   [0, 3, 244, 284, 493, 554, 664, 682, 787, 842,...   135.448963  2.063772
# 9   [0, 3, 244, 284, 493, 554, 664, 682, 787, 842,...   120.624487  1.946358
# 10  [0, 3, 186, 244, 284, 493, 554, 664, 682, 787,...    90.601625  1.788088
# 11  [0, 3, 186, 244, 284, 493, 554, 664, 682, 787,...    81.357093  1.710090
# 12  [0, 237, 244, 284, 492, 552, 554, 556, 664, 68...    55.719159  1.533311
# 13  [0, 237, 244, 284, 492, 552, 554, 556, 558, 66...    51.876241  1.470982
#
#         Silh     Cal-Har  Dav-Bold  Avg-Silh  Avg-Cal-Har  Avg-Dav-Bold
# 0   0.191917  609.442343  3.490241  0.297464   579.615649      2.765555
# 1   0.168557  520.706908  8.777928  0.361712   492.073092      0.910005
# 2   0.166938  541.486137  2.237017  0.470157   561.328663      0.756607
# 3   0.140647  515.485316  3.087407  0.454800   458.806916      0.812620
# 4   0.131176  462.514553  3.362688  0.448195   405.940064      0.853905
# 5   0.088632  426.379620  3.321983  0.458289   368.679214      0.961876
# 6   0.090352  404.792785  3.236274  0.426957   211.675822      1.084985
# 7   0.092300  378.370472  3.510031  0.389403   165.680902      1.240856
# 8   0.089382  343.879705  5.801489  0.377525    84.051367      1.307446
# 9   0.086382  313.796493  6.034127  0.351121    75.474343      1.528642
# 10  0.025808  303.845663  4.662161  0.325444    58.921628      1.474489
# 11  0.022889  281.574787  4.942946  0.307461    53.566801      1.649087
# 12 -0.107162  253.097503  6.237546  0.268353    36.650674      2.539826
# 13 -0.148693  236.167523  5.949760  0.269724    34.967532      2.462721

# %%
umap_best_result = SDA.analytics.best_result(umap_result, key = 'Avg-Silh', n_stages = N_STAGES)
umap_edges = umap_best_result['St_edges']

print('Features:', features.shape)
print('Best features:', best_features.shape)
print('UMAP features:', umap_features.shape)

print('Explained variance 15-765:', explained_variance(best_features, umap_features))
print('Explained variance 15-all:', explained_variance(features, umap_features))

print('Outer:', SDA.clustquality.cluster_metrics_ground(edges_true, umap_edges))

print('Inner (15):', SDA.clustquality.calc_stage_metr_noground(umap_features, umap_edges).mean().to_dict())
print('Inner (765):', SDA.clustquality.calc_stage_metr_noground(best_features, umap_edges).mean().to_dict())
print('Inner (all):', SDA.clustquality.calc_stage_metr_noground(features, umap_edges).mean().to_dict())
# Out:
# Features: (1046, 19563)
# Best features: (1046, 765)
# UMAP features: (1046, 15)
# Explained variance 15-765: 0.3422217257998321
# Explained variance 15-all: 0.14679260639896052
# Outer: {'AMI': 0.8708619833167367, 'ARI': 0.7725567414667996, 'FMI': 0.8106495805228112}
# Inner (15): {'Silh': 0.4269565939903259, 'Cal-Har': 211.6758216247128, 'Dav-Bold': 1.0849845305825214}
# Inner (765): {'Silh': 0.1178591389331013, 'Cal-Har': 24.473057112493024, 'Dav-Bold': 2.729181312993469}
# Inner (all): {'Silh': 0.04488074049083551, 'Cal-Har': 9.47753889677005, 'Dav-Bold': 4.49777586580225}

# %% [markdown]
# ### PCA

# %%
pca = sklearn.decomposition.PCA(n_components = 15, svd_solver = "full", random_state = 42)
pca_features = pca.fit_transform(best_features)

print('Explained variance', round(pca.explained_variance_ratio_.sum(), 2))
print([ round(x, 3) for x in pca.explained_variance_ratio_ ])
print(pca_features.shape)
print(explained_variance(best_features, pca_features))
# Out:
# Explained variance 0.49
# [0.211, 0.064, 0.036, 0.028, 0.019, 0.016, 0.015, 0.014, 0.013, 0.012, 0.012, 0.012, 0.011, 0.011, 0.011]
# (1046, 15)
# 0.4864660073929153

# %%
pca_result, _ = SDA.SDA(n_jobs = 15, scale = False, verbose = True).apply(pca_features)
display(SDA.analytics.best_results(pca_result, key = 'Avg-Silh'))
# Out:
# Applying to 1046 samples with 15 features each
# Running stage 1
#   0%|          | 0/589 [00:00<?, ?it/s]
# Running stage 2
#   0%|          | 0/672 [00:00<?, ?it/s]
#     St_len_min  K_nb_max  N_cl_max  N_stages  Cl_cen  \
# 0            0        35        10         3  Median
# 1            0        45        10         4    Mode
# 2            0        45        10         5    Mode
# 3           20        35        20         6    Mode
# 4           20        35        20         7    Mode
# 5           20        40        20         8    Mode
# 6           20        40        20         9    Mode
# 7            0        35        20        10    Mode
# 8           60        35        10        11  Median
# 9           60        35        20        12  Median
# 10           0        45        15        13    Mode
# 11          20        35        20        14  Median
# 12           0        45        20        15  Median
# 13           0        35        20        16  Median
#
#                                              St_edges     Ward_dist  \
# 0                                 [0, 213, 682, 1046]  35145.347472
# 1                            [0, 239, 682, 795, 1046]  38089.486164
# 2                       [0, 239, 554, 682, 795, 1046]  36838.467684
# 3                  [0, 213, 556, 682, 856, 976, 1046]  34756.845805
# 4             [0, 141, 213, 556, 682, 856, 976, 1046]  25478.954688
# 5         [0, 55, 213, 313, 556, 682, 856, 976, 1046]  20688.313862
# 6    [0, 55, 213, 313, 556, 682, 792, 856, 976, 1046]  16431.631619
# 7   [0, 18, 141, 213, 349, 556, 682, 792, 856, 976...  14061.293589
# 8   [0, 167, 210, 239, 266, 340, 554, 682, 792, 85...  11695.398856
# 9   [0, 81, 185, 210, 239, 278, 349, 554, 682, 792...  10725.397483
# 10  [0, 3, 80, 141, 213, 239, 313, 485, 554, 682, ...   8646.236623
# 11  [0, 33, 141, 210, 239, 262, 340, 485, 554, 659...   5815.019537
# 12  [0, 24, 80, 142, 209, 262, 313, 393, 485, 554,...   5652.922255
# 13  [0, 24, 55, 142, 210, 239, 266, 343, 393, 485,...   5227.009816
#
#      Cen_dist      Silh     Cal-Har  Dav-Bold  Avg-Silh  Avg-Cal-Har  \
# 0   13.158251  0.074215  124.241892  4.429616  0.152337   122.721051
# 1   18.229403  0.053647  118.198456  6.682038  0.200516   137.295645
# 2   20.618401  0.062161  133.886675  2.902583  0.281205   157.921585
# 3   20.612277  0.055596  124.753990  3.768089  0.283627   152.129359
# 4   18.574950  0.028746  108.183795  3.897923  0.248688   112.133862
# 5   16.705467  0.029576   99.526098  3.513772  0.218665    90.368112
# 6   16.066765  0.008520   93.680736  3.925440  0.207043    73.424832
# 7   15.257765 -0.005532   83.791576  3.776429  0.189200    62.711891
# 8   13.650928 -0.032317   74.425012  3.927537  0.166849    52.925911
# 9   12.947615 -0.027998   70.182669  4.139875  0.157623    47.965898
# 10  13.329519 -0.034081   65.584916  4.445223  0.155089    38.078588
# 11  12.730224 -0.030838   63.886672  4.155619  0.145660    27.581687
# 12  12.408623 -0.020153   60.399451  4.369212  0.145303    27.836268
# 13  12.269929 -0.036285   57.186343  4.212768  0.140193    25.534308
#
#     Avg-Dav-Bold
# 0       3.626449
# 1       1.568596
# 2       1.382615
# 3       1.356516
# 4       1.651062
# 5       1.767305
# 6       1.773108
# 7       1.944495
# 8       2.110736
# 9       2.358974
# 10      2.373712
# 11      2.172275
# 12      2.361100
# 13      2.240144

# %%
pca_best_result = SDA.analytics.best_result(pca_result, key = 'Avg-Silh', n_stages = N_STAGES)
pca_edges = pca_best_result['St_edges']

print('Features:', features.shape)
print('Best features:', best_features.shape)
print('PCA features:', pca_features.shape)

print('Explained variance 15-765:', explained_variance(best_features, pca_features))
print('Explained variance 15-all:', explained_variance(features, pca_features))

print('Outer:', SDA.clustquality.cluster_metrics_ground(edges_true, pca_edges))

print('Inner (15):', SDA.clustquality.calc_stage_metr_noground(pca_features, pca_edges).mean().to_dict())
print('Inner (765):', SDA.clustquality.calc_stage_metr_noground(best_features, pca_edges).mean().to_dict())
print('Inner (all):', SDA.clustquality.calc_stage_metr_noground(features, pca_edges).mean().to_dict())
# Out:
# Features: (1046, 19563)
# Best features: (1046, 765)
# PCA features: (1046, 15)
# Explained variance 15-765: 0.4864660073929153
# Explained variance 15-all: 0.20552026612067126
# Outer: {'AMI': 0.8551101496383234, 'ARI': 0.7216299947154539, 'FMI': 0.7609127844904733}
# Inner (15): {'Silh': 0.20704251985090527, 'Cal-Har': 73.42483216299364, 'Dav-Bold': 1.7731084140173086}
# Inner (765): {'Silh': 0.09140506261405176, 'Cal-Har': 26.789423143863274, 'Dav-Bold': 3.021600848334752}
# Inner (all): {'Silh': 0.03274823026774569, 'Cal-Har': 10.093835018732683, 'Dav-Bold': 5.206962015523273}

# %% [markdown]
# ### Traditional features

# %%
df_ft_psd_loc_db = pandas.read_feather(f'{subj}/src/df_ft_psd_loc_db.feather')
df_ft_psd_ind_loc_log = pandas.read_feather(f'{subj}/src/df_ft_psd_ind_loc_log.feather')
df_ft_coh_ind_loc = pandas.read_feather(f'{subj}/src/df_ft_coh_ind_loc.feather')
df_ft_plv_ind_loc = pandas.read_feather(f'{subj}/src/df_ft_plv_ind_loc.feather')

features_neuro = pandas.concat([ df_ft_psd_loc_db, df_ft_psd_ind_loc_log, df_ft_coh_ind_loc, df_ft_plv_ind_loc ], axis = 1)
print(features_neuro.shape)

features_neuro = sklearn.preprocessing.StandardScaler().fit_transform(features_neuro)
print(features_neuro.shape)
# Out:
# (1046, 765)
# (1046, 765)

# %% [markdown]
# #### UMAP

# %%
neuro_umap = umap.UMAP(n_components = 15, random_state = 42)
features_neuro_umap = neuro_umap.fit_transform(features_neuro)
print(features_neuro_umap.shape)
# Out:
# (1046, 15)

# %%
neuro_umap_result, _ = SDA.SDA(n_jobs = 15, scale = False, verbose = True).apply(features_neuro_umap)
display(SDA.analytics.best_results(neuro_umap_result, key = 'Avg-Silh'))
# Out:
# Applying to 1046 samples with 15 features each
# Running stage 1
#   0%|          | 0/589 [00:00<?, ?it/s]
# Running stage 2
#   0%|          | 0/672 [00:00<?, ?it/s]
#     St_len_min  K_nb_max  N_cl_max  N_stages  Cl_cen  \
# 0            0        35        15         3  Median
# 1            0        35        10         4    Mode
# 2            0        35        10         5    Mode
# 3           40        45        15         6  Median
# 4            0        35        10         7  Median
# 5            0        35        10         8  Median
# 6            0        35        10         9  Median
# 7            0        35        15        10  Median
# 8            0        35        15        11  Median
# 9            0        35        10        12  Median
# 10           0        40        10        13    Mean
# 11           0        40        10        14    Mean
# 12          20        35        15        15  Median
# 13          20        35        10        16  Median
#
#                                              St_edges    Ward_dist  Cen_dist  \
# 0                                 [0, 232, 681, 1046]  2337.918949  3.473309
# 1                            [0, 263, 681, 777, 1046]  2692.104897  5.128663
# 2                       [0, 263, 555, 681, 857, 1046]  1582.330946  3.882507
# 3                  [0, 263, 555, 681, 777, 976, 1046]  1529.732542  4.037761
# 4             [0, 103, 263, 555, 681, 777, 976, 1046]  1074.482228  3.629237
# 5        [0, 103, 263, 555, 681, 777, 857, 976, 1046]   871.482210  3.530660
# 6   [0, 103, 263, 492, 555, 681, 777, 857, 976, 1046]   715.690314  3.341220
# 7   [0, 103, 194, 263, 492, 555, 681, 777, 857, 97...   525.656640  2.982591
# 8   [0, 39, 103, 194, 263, 492, 555, 681, 777, 857...   468.736672  2.785580
# 9   [0, 39, 103, 194, 232, 263, 492, 555, 681, 777...   399.733147  2.548545
# 10  [0, 39, 102, 122, 194, 232, 263, 492, 555, 681...   361.645602  2.357163
# 11  [0, 39, 102, 122, 194, 232, 263, 282, 492, 555...   324.989205  2.183902
# 12  [0, 39, 91, 103, 122, 168, 194, 232, 263, 492,...   307.256058  2.062509
# 13  [0, 39, 91, 103, 122, 194, 232, 263, 492, 555,...   283.048430  2.077090
#
#         Silh     Cal-Har  Dav-Bold  Avg-Silh  Avg-Cal-Har  Avg-Dav-Bold
# 0   0.225711  567.432745  1.859608  0.332809   606.796648      1.545486
# 1   0.249266  754.597017  2.894817  0.587176   804.180915      0.554250
# 2   0.239389  589.867979  1.457409  0.453061   533.176090      0.871468
# 3   0.218712  684.150707  1.750357  0.494924   695.206290      0.910106
# 4   0.183207  712.889985  1.641383  0.478156   547.630230      0.904382
# 5   0.195523  739.037591  2.466327  0.519981   502.692844      0.727290
# 6   0.228852  756.272604  2.270272  0.510964   452.897032      0.736405
# 7   0.217626  735.812963  2.173425  0.487485   348.323992      0.794628
# 8   0.223040  693.776986  2.035597  0.495106   325.403070      0.780897
# 9   0.212193  635.193597  2.226929  0.460038   276.303980      0.959830
# 10  0.193598  586.801652  2.187560  0.431485   245.693209      1.022772
# 11  0.165424  548.527395  2.198844  0.408356   221.577918      1.132259
# 12  0.189637  508.251704  2.248638  0.395527   217.239215      1.204403
# 13  0.160095  507.285725  2.160859  0.388468   203.150275      1.084075

# %%
neuro_umap_best_result = SDA.analytics.best_result(neuro_umap_result, key = 'Avg-Silh', n_stages = N_STAGES)
neuro_umap_edges = neuro_umap_best_result['St_edges']

print('Neuro features:', features_neuro.shape)
print('UMAP neuro features:', features_neuro_umap.shape)

print('Explained variance 15-765:', explained_variance(features_neuro, features_neuro_umap))

print('Outer:', SDA.clustquality.cluster_metrics_ground(edges_true, neuro_umap_edges))

print('Inner (15):', SDA.clustquality.calc_stage_metr_noground(features_neuro_umap, neuro_umap_edges).mean().to_dict())
print('Inner (765):', SDA.clustquality.calc_stage_metr_noground(features_neuro, neuro_umap_edges).mean().to_dict())
# Out:
# Neuro features: (1046, 765)
# UMAP neuro features: (1046, 15)
# Explained variance 15-765: 0.50961167309074
# Outer: {'AMI': 0.8989658031918278, 'ARI': 0.8201120691706356, 'FMI': 0.8459071662662822}
# Inner (15): {'Silh': 0.5109639167785645, 'Cal-Har': 452.89703155772366, 'Dav-Bold': 0.7364054709635279}
# Inner (765): {'Silh': 0.13754202043469593, 'Cal-Har': 42.38118519698051, 'Dav-Bold': 2.238258625900672}

# %% [markdown]
# #### PCA

# %%
neuro_pca = sklearn.decomposition.PCA(n_components = 15, svd_solver = "full", random_state = 42)
features_neuro_pca = neuro_pca.fit_transform(features_neuro)

print('Explained variance', round(neuro_pca.explained_variance_ratio_.sum(), 2))
print([ round(x, 3) for x in neuro_pca.explained_variance_ratio_ ])
print(features_neuro_pca.shape)
print(explained_variance(features_neuro, features_neuro_pca))
# Out:
# Explained variance 0.71
# [0.211, 0.156, 0.069, 0.063, 0.046, 0.032, 0.026, 0.02, 0.018, 0.015, 0.013, 0.012, 0.01, 0.009, 0.009]
# (1046, 15)
# 0.7106773827080092

# %%
neuro_pca_result, _ = SDA.SDA(n_jobs = 15, scale = False, verbose = True).apply(features_neuro_pca)
display(SDA.analytics.best_results(neuro_pca_result, key = 'Avg-Silh'))
# Out:
# Applying to 1046 samples with 15 features each
# Running stage 1
#   0%|          | 0/589 [00:00<?, ?it/s]
# Running stage 2
#   0%|          | 0/672 [00:00<?, ?it/s]
#     St_len_min  K_nb_max  N_cl_max  N_stages  Cl_cen  \
# 0            0        35        10         3    Mode
# 1           20        40        15         4  Median
# 2           40        50        10         5  Median
# 3            0        35        20         6    Mode
# 4            0        40        20         7    Mode
# 5           60        45        20         8  Median
# 6            0        45        20         9    Mode
# 7           20        40        15        10    Mode
# 8           40        40        15        11    Mode
# 9           40        40        20        12    Mode
# 10          40        40        20        13    Mode
# 11          20        50        15        14    Mode
# 12           0        40        20        15  Median
# 13           0        40        20        16    Mode
#
#                                              St_edges     Ward_dist  \
# 0                                 [0, 282, 560, 1046]  42308.816307
# 1                            [0, 168, 560, 857, 1046]  33307.136107
# 2                       [0, 178, 560, 682, 857, 1046]  45198.297789
# 3                   [0, 39, 282, 560, 682, 857, 1046]  34637.660711
# 4              [0, 39, 282, 560, 682, 857, 976, 1046]  33803.157325
# 5        [0, 104, 277, 557, 682, 784, 857, 976, 1046]  27148.763733
# 6    [0, 39, 282, 492, 560, 682, 784, 857, 976, 1046]  24209.602081
# 7   [0, 92, 154, 282, 492, 560, 682, 784, 857, 976...  19921.966427
# 8   [0, 92, 154, 282, 492, 560, 609, 682, 784, 857...  17433.673781
# 9   [0, 95, 154, 282, 492, 560, 609, 682, 784, 857...  15496.871841
# 10  [0, 95, 154, 237, 282, 492, 560, 609, 682, 784...  13579.566230
# 11  [0, 39, 92, 154, 282, 360, 492, 560, 609, 682,...  12688.225406
# 12  [0, 39, 95, 156, 235, 282, 360, 492, 560, 609,...  11884.059588
# 13  [0, 39, 95, 154, 237, 282, 360, 492, 560, 609,...  11185.853541
#
#      Cen_dist      Silh     Cal-Har  Dav-Bold  Avg-Silh  Avg-Cal-Har  \
# 0   16.400094  0.072681  114.988709  2.722181  0.125930   108.777275
# 1   15.081889  0.070873   89.780730  3.560225  0.127895    86.288835
# 2   21.835308  0.084183  105.595294  2.586946  0.211379   121.129124
# 3   20.807593  0.058036   91.372564  2.433889  0.189075    94.179967
# 4   21.727724  0.027373   87.867345  3.085920  0.197685    90.699464
# 5   20.782267  0.051638   88.107028  3.174767  0.202978    77.226016
# 6   21.382082  0.040342   81.951371  2.922261  0.199396    69.908675
# 7   19.978023  0.055157   80.814883  2.941300  0.197371    59.065692
# 8   20.010478  0.047344   76.533681  2.935801  0.205210    56.018632
# 9   19.770975  0.048565   72.453995  2.928984  0.204760    51.143214
# 10  18.985930  0.046040   68.411579  2.936972  0.194270    44.905479
# 11  18.252759  0.028141   65.165998  2.987215  0.190209    43.144643
# 12  17.899476  0.032962   62.514331  2.960100  0.186891    40.697518
# 13  18.118280  0.002749   58.623527  2.957891  0.185803    38.294560
#
#     Avg-Dav-Bold
# 0       2.438303
# 1       3.119853
# 2       1.797900
# 3       1.796114
# 4       1.694186
# 5       1.764923
# 6       1.637018
# 7       1.797313
# 8       1.818006
# 9       1.887942
# 10      1.977766
# 11      2.042964
# 12      2.074625
# 13      2.016579

# %%
neuro_pca_best_result = SDA.analytics.best_result(neuro_pca_result, key = 'Avg-Silh', n_stages = N_STAGES)
neuro_pca_edges = neuro_pca_best_result['St_edges']

print('Neuro features:', features_neuro.shape)
print('PCA neuro features:', features_neuro_pca.shape)

print('Explained variance 15-765:', explained_variance(features_neuro, features_neuro_pca))

print('Outer:', SDA.clustquality.cluster_metrics_ground(edges_true, neuro_pca_edges))

print('Inner (15):', SDA.clustquality.calc_stage_metr_noground(features_neuro_pca, neuro_pca_edges).mean().to_dict())
print('Inner (765):', SDA.clustquality.calc_stage_metr_noground(features_neuro, neuro_pca_edges).mean().to_dict())
# Out:
# Neuro features: (1046, 765)
# PCA neuro features: (1046, 15)
# Explained variance 15-765: 0.7106773827080092
# Outer: {'AMI': 1.0, 'ARI': 1.0, 'FMI': 1.0}
# Inner (15): {'Silh': 0.1993961405684552, 'Cal-Har': 69.90867530727269, 'Dav-Bold': 1.637017876621227}
# Inner (765): {'Silh': 0.13823275074674224, 'Cal-Har': 44.432973449387084, 'Dav-Bold': 2.115450457714017}
